# %% [markdown]
# <span style="color:red">WIP. Markdown tips:  https://www.markdownguide.org/basic-syntax/#</span>

# %% [markdown]
# <h1><center> 4AB00. Intermediate assignment</center></h1>
# <h2><center> Modeling and simulation of an autonomous vehicle storage and retrieval system</center></h2>
#
# # 1 Subject
#
# Today's competitive environment, in which deliveries need to be faster and order sizes become smaller, forces material handling providers to progressively develop new and better solutions. A recent development in automated material-handling technology for unit load storage and retrieval is the autonomous vehicle storage and retrieval system (AVS/RS). Figure 1 shows a representation of an AVS/RS for the handling of totes, while Figure 2 illustrates a single tier (floor, level). The storage racks are single-deep and double-sided. Each storage position is of the same size and can hold one tote. Lifts are mounted at fixed locations at one end of each storage aisle. The input/output (I/O) point is located at the first tier beside each lift. Autonomous vehicles are dedicated to a storage aisle within a specific tier (so-called tier-captive configuration). The first position on either side of the storage aisle in all tiers serves as a buffer and is used to manage the transfer of totes between vehicles and lifts (see Figure 2). One buffer (out) handles totes which have been retrieved, the other one (in), located on the other side of the storage aisle, handles the totes to be stored. The presence of these buffers allows the lift and vehicle to work independently of each other.
#
# The throughput performance of AVS/RS systems can be affected by design decisions (such as number of tiers, number of aisles, and depth of aisles) as well as operational decisions (such as tote storage location and order assignment).
#
# Figure 1: AVS/RS with tier-captive configuration [1] | Figure 2: Single tier in AVS/RS [1]
# - | -
# <img src="./Course_4DC10/nickpy-exercises/figures/avs.png" alt="drawing" width="400"/> | <img src="./Course_4DC10/nickpy-exercises/figures/avrs2.png" alt="drawing" width="400"/>

# %% [markdown]
# # 2 Goal
# The goal of this assignment is to study this new material handling solution by using computer simulation. This study can be restricted to the retrieval process only, i.e., the vehicles perform only single retrieval cycles. Clearly, the retrieval phase is the most critical activity from an organisational viewpoint, as it is directly related to customer service level and &mdash; in contrast to the storage phase &mdash; it cannot be postponed to a period of low workload.
#
# The objectives of this assignment can be summarized as follows:
# - Develop a simulation model of one aisle that consists of Level tiers with retrieval process to assess the system performance in terms of throughput and flow time.
# - Systematically develop the model process by process, and verify and validate each process using analytical results.
# - Investigate design trade-offs, i.e., via different layouts (number of columns and tiers), for this material handling system.

# %% [markdown]
# # 3 Description of the AVS/RS
# The AVS/RS is a fully automated system that can store and retrieve unit loads. The unit loads are placed in totes, a type of box, and these totes are placed in a designated aisle and column for storage. When retrieved, an autonomous vehicle places the totes in a buffer at the end of the aisle. There is one autonomous vehicle for every aisle within the tier. This is called the tier-captive configuration. From the buffer, the totes are picked by a lift that serves all tiers inone aisle, see Figure 2. In this assignment only one aisle that consists of `Level` tiers has to be modelled. Each aisle has depth number of columns of width `dv` metres and height `dl` metres.
#
# Requests for a tote arrive for each tier, asking for a tote with a random (uniformly distributed) column assigned to it. The inter arrival time of requests is exponentially distributed with mean value `arrive`.
#
# The vehicles transport totes along the aisle (one vehicle per tier). The time taken by the vehicle to process an order depends on the tote's location. The vehicle has to travel to this location, load the tote (it takes a fixed amount of time equal to `lv` seconds), then go back to the end of the aisle and, finally, unload the tote to the buffer (again this takes `lv` seconds). The speed profile of each vehicle is described as follows. First, the vehicle goes with a constant acceleration `av` *m/s$^2$* until it reaches its maximum velocity `vmaxv`, then it moves with this velocity and decelerates with a constant deceleration `av` to approach its destination point. If the tote is located too close to the end of the aisle, it is possible that the vehicle will not reach its maximum speed.
#
# The vehicles unload the totes to a location where it is picked up by the lift. At any given time only one tote per tier is allowed to occupy such a position.
#
# The lift transports the totes from every tier to the ground floor. The processing time depends on the tote's location and the fixed time to load and unload the tote (`ll` seconds for loading and `ll` seconds for unloading). The maximum speed of the lift is `vmaxl` *m/s* with a speed profile similar to that of the vehicles (constant acceleration/deceleration of `al` *m/s<sup>2</sup>*).

# %% [markdown]
# # 4 Modeling of the AVS/RS
# The model consists of several processes communicating via channels, see Figure 3.
#
# | Figure 3: The processes in the model |
# -
# <img src="./Course_4DC10/nickpy-exercises/figures/avrs.png" alt="drawing" width="400"/>
#
# A brief description of the processes is given below:
# - **G:** The generator models the arrival of orders for totes. There is one generator per tier.
# - **DB:** The demand buffer stores the orders to be picked up by the vehicles. The vehicle processes the orders under first-come-first-serve policy. It can always receive a tote, but it releases a tote only when the vehicle is ready to pick it up.
# - **V:** The vehicle can be modeled as a server with a variable processing time.
# - **GDV:** The process consisting of a Generator, Demand Buffer and Vehicle for one tier of the AVS/RS system.
# - **B:** The buffer stores the totes from the vehicles awaiting for a pick-up by the lift. The buffer operates under first-come-first-serve policy and has a finite capacity of `bc` totes per tier. So, every tier has a buffer location of finite capacity of `bc` totes. All those locations together form the buffer B that accommodates all the totes which are processed by the same lift. When the buffer is not empty (there is at least one tote on one of the tiers), the buffer sends information about the tier of the longest waiting tote to the lift upon request. This information is used by the lift to determine the location of the tote (the number of the tier the tote is located in). Once the lift is ready to pick it up, the tote is released to the lift. There are two types of queues in the buffer: `xs` contains all the totes to be picked up by the lift and there are Level counters `n` counting the totes from the corresponding tier.
# - **L:** The lift, similar to the process V, is modeled as a machine with a variable processing time. A lift first receives a destination tier. Then the process delays for time required for the lift to go to the tote location and pick up the tote. Then it receives the tote, and next it delays for the time required to go to the ground floor and to unload the tote. After that the lift process is ready to release the tote to the Exit process.
# - **E:** In the exit process all the data related to each tote are collected. This process calculates the average throughput and the average flow-time. The number of totes to be processed by the AVS/RS during one simulation run is determined by the constant `Number_of_orders`.

# %% [markdown]
# # 5 Remark concerning report
# The report has to contain concise answers to the questions posed. If code has to be presented, present the
# specification only of the modified process. Avoid unnecessary long explanations, however answers to analytical
# questions without an argument will result in no points.
#
#
# <span style="color:red">(Dit stuk moet natuurlijk nog aangepast worden)</span>

# %% [markdown]
# # 6 Assignment
# When making a SimPy specification, one does not build an entire model and then starts debugging. A model is build step by step. During each step proper functionality is checked. We therefore model one process at a time, and connect the process with a Generator and/or Exit process to test proper functionality. In order to test proper functionality we first use analytical methods to determine the expected outcome. Then we run simulations to verify if these outcomes are indeed obtained. If that is the case, we can be more convinced that the process has been modeled correctly.
#
# First, we initialize our simulation

# %%
# %reset -f
from numpy import random
import simpy
import math
import numpy
numpy.seterr(divide='ignore')
from Course_4DC10.simChi.core.channel_select import Channel, process, selected, Environment
from dataclasses import dataclass

# %% [markdown]
# ## 6.1 Exercise 1: Generator (5 points)
# So the first step is to write a proper generator for a tier. To that end, the first model we build consists of (only) a Generator process and an Exit process collecting the totes generated by the Generator. The inter arrival time of requests is exponentially distributed with mean `arrive`. The requested tote should be retrieved from a random (uniformly distributed) column, where there are `depth` columns in total.

# %% [markdown]
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process and the exit process.

# %% [markdown]
# Answer: <input type="text" id="6.1.a" name="6.1.a"/>
#
# <span style="color:red">(werkt nog niet)</span>

# %% [markdown]
# b. Complete the simulation code from the following template:

# %%
# =================================
# # Global variables
# =================================
arrive = 70.0             # inter arrival time of requests
depth  = 55               # the number of columns
number_of_orders = 10000  # the number of orders to process

# =================================
# # Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0.0
    column: int = 0

# =================================
# # Generator definition
# =================================
def Generator(env, sending_channel):
    ### BEGIN SOLUTION
    ta_dist = lambda: random.exponential(arrive)
    column_dist = lambda:  random.randint(1, depth)
    ### END SOLUTION
    x = Tote()
    while True:
        x.entrytime = env.now
        # x.column = ..... 
        ### BEGIN SOLUTION
        x.column = column_dist()
        ### END SOLUTION
        send = sending_channel.send(x)
        yield env.select(send)
        # delay = ..... 
        ### BEGIN SOLUTION
        delay = env.timeout(ta_dist())
        ### END SOLUTION
        yield delay


# =================================
# # Exit definition
# =================================
def Exit(env, receiving_channel):
    x = Tote()
    mphi = 0
    for i in range(1, number_of_orders + 1):
        receive = receiving_channel.receive()
        x = yield env.select(receive)
        mphi = (i - 1) / i * mphi + (env.now - x.entrytime) / i
        print("tote = %d; Entrytime = %10.4f; Column = %2d; Mean throughput = %8.6f; Mean flowtime = %6.4f\n" 
            %(i , x.entrytime, x.column, numpy.float64(i) / env.now, mphi ) )


# =================================
# # Main
# =================================
env = Environment()
a = Channel(env)
G = env.process(Generator(env, a))
E = env.process(Exit(env, a))
env.run(until=E)
print ("simulation has ended")
# Out:
# tote = 1; Entrytime =     0.0000; Column = 33; Mean throughput =      inf; Mean flowtime = 0.0000
#
# tote = 2; Entrytime =    45.0308; Column = 10; Mean throughput = 0.044414; Mean flowtime = 0.0000
#
# tote = 3; Entrytime =   139.5073; Column = 49; Mean throughput = 0.021504; Mean flowtime = 0.0000
#
# tote = 4; Entrytime =   173.7481; Column =  3; Mean throughput = 0.023022; Mean flowtime = 0.0000
#
# tote = 5; Entrytime =   185.7169; Column =  8; Mean throughput = 0.026923; Mean flowtime = 0.0000
#
# tote = 6; Entrytime =   188.1694; Column =  8; Mean throughput = 0.031886; Mean flowtime = 0.0000
#
# tote = 7; Entrytime =   218.1403; Column =  4; Mean throughput = 0.032089; Mean flowtime = 0.0000
#
# tote = 8; Entrytime =   254.4899; Column = 24; Mean throughput = 0.031435; Mean flowtime = 0.0000
#
# tote = 9; Entrytime =   307.5849; Column =  9; Mean throughput = 0.029260; Mean flowtime = 0.0000
#
# tote = 10; Entrytime =   371.4131; Column = 51; Mean throughput = 0.026924; Mean flowtime = 0.0000
#
# tote = 11; Entrytime =   390.4666; Column = 40; Mean throughput = 0.028171; Mean flowtime = 0.0000
#
# tote = 12; Entrytime =   562.9132; Column =  3; Mean throughput = 0.021318; Mean flowtime = 0.0000
#
# tote = 13; Entrytime =   610.4238; Column = 38; Mean throughput = 0.021297; Mean flowtime = 0.0000
#
# tote = 14; Entrytime =   662.6217; Column = 38; Mean throughput = 0.021128; Mean flowtime = 0.0000
#
# tote = 15; Entrytime =   774.1195; Column = 48; Mean throughput = 0.019377; Mean flowtime = 0.0000
#
# tote = 16; Entrytime =   800.3532; Column = 27; Mean throughput = 0.019991; Mean flowtime = 0.0000
#
# tote = 17; Entrytime =   929.1176; Column = 41; Mean throughput = 0.018297; Mean flowtime = 0.0000
#
# tote = 18; Entrytime =  1163.5995; Column = 45; Mean throughput = 0.015469; Mean flowtime = 0.0000
#
# tote = 19; Entrytime =  1247.0988; Column = 14; Mean throughput = 0.015235; Mean flowtime = 0.0000
#
# tote = 20; Entrytime =  1281.4745; Column = 54; Mean throughput = 0.015607; Mean flowtime = 0.0000
#
# tote = 21; Entrytime =  1303.6547; Column = 53; Mean throughput = 0.016109; Mean flowtime = 0.0000
#
# tote = 22; Entrytime =  1370.9358; Column = 50; Mean throughput = 0.016047; Mean flowtime = 0.0000
#
# tote = 23; Entrytime =  1557.1591; Column = 12; Mean throughput = 0.014770; Mean flowtime = 0.0000
#
# tote = 24; Entrytime =  1616.7944; Column = 12; Mean throughput = 0.014844; Mean flowtime = 0.0000
#
# tote = 25; Entrytime =  1632.5823; Column = 53; Mean throughput = 0.015313; Mean flowtime = 0.0000
#
# tote = 26; Entrytime =  1676.0400; Column = 16; Mean throughput = 0.015513; Mean flowtime = 0.0000
#
# tote = 27; Entrytime =  1686.2432; Column = 34; Mean throughput = 0.016012; Mean flowtime = 0.0000
#
# tote = 28; Entrytime =  1792.5167; Column = 54; Mean throughput = 0.015620; Mean flowtime = 0.0000
#
# tote = 29; Entrytime =  2061.4704; Column = 30; Mean throughput = 0.014068; Mean flowtime = 0.0000
#
# tote = 30; Entrytime =  2123.1110; Column =  6; Mean throughput = 0.014130; Mean flowtime = 0.0000
#
# tote = 31; Entrytime =  2193.2456; Column = 26; Mean throughput = 0.014134; Mean flowtime = 0.0000
#
# tote = 32; Entrytime =  2387.4576; Column = 51; Mean throughput = 0.013403; Mean flowtime = 0.0000
#
# tote = 33; Entrytime =  2431.7107; Column = 10; Mean throughput = 0.013571; Mean flowtime = 0.0000
#
# tote = 34; Entrytime =  2544.3810; Column = 36; Mean throughput = 0.013363; Mean flowtime = 0.0000
#
# tote = 35; Entrytime =  2571.2089; Column = 44; Mean throughput = 0.013612; Mean flowtime = 0.0000
#
# tote = 36; Entrytime =  2651.9999; Column = 41; Mean throughput = 0.013575; Mean flowtime = 0.0000
#
# tote = 37; Entrytime =  2686.2756; Column = 26; Mean throughput = 0.013774; Mean flowtime = 0.0000
#
# tote = 38; Entrytime =  2776.1421; Column = 32; Mean throughput = 0.013688; Mean flowtime = 0.0000
#
# tote = 39; Entrytime =  2825.8502; Column = 11; Mean throughput = 0.013801; Mean flowtime = 0.0000
#
# tote = 40; Entrytime =  2833.4270; Column =  9; Mean throughput = 0.014117; Mean flowtime = 0.0000
#
# tote = 41; Entrytime =  2929.5179; Column = 54; Mean throughput = 0.013995; Mean flowtime = 0.0000
#
# tote = 42; Entrytime =  2930.4354; Column = 18; Mean throughput = 0.014332; Mean flowtime = 0.0000
#
# tote = 43; Entrytime =  2933.7441; Column = 51; Mean throughput = 0.014657; Mean flowtime = 0.0000
#
# tote = 44; Entrytime =  3027.1886; Column =  3; Mean throughput = 0.014535; Mean flowtime = 0.0000
#
# tote = 45; Entrytime =  3138.1872; Column =  6; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 46; Entrytime =  3178.0924; Column = 26; Mean throughput = 0.014474; Mean flowtime = 0.0000
#
# tote = 47; Entrytime =  3186.3961; Column = 20; Mean throughput = 0.014750; Mean flowtime = 0.0000
#
# tote = 48; Entrytime =  3237.7841; Column = 20; Mean throughput = 0.014825; Mean flowtime = 0.0000
#
# tote = 49; Entrytime =  3330.9455; Column =  9; Mean throughput = 0.014711; Mean flowtime = 0.0000
#
# tote = 50; Entrytime =  3428.8983; Column = 38; Mean throughput = 0.014582; Mean flowtime = 0.0000
#
# tote = 51; Entrytime =  3558.3795; Column = 31; Mean throughput = 0.014332; Mean flowtime = 0.0000
#
# tote = 52; Entrytime =  3707.7608; Column = 49; Mean throughput = 0.014025; Mean flowtime = 0.0000
#
# tote = 53; Entrytime =  3742.4908; Column = 20; Mean throughput = 0.014162; Mean flowtime = 0.0000
#
# tote = 54; Entrytime =  3793.8480; Column = 30; Mean throughput = 0.014234; Mean flowtime = 0.0000
#
# tote = 55; Entrytime =  3832.9602; Column = 25; Mean throughput = 0.014349; Mean flowtime = 0.0000
#
# tote = 56; Entrytime =  3849.2747; Column = 42; Mean throughput = 0.014548; Mean flowtime = 0.0000
#
# tote = 57; Entrytime =  3912.9572; Column = 51; Mean throughput = 0.014567; Mean flowtime = 0.0000
#
# tote = 58; Entrytime =  3933.3696; Column = 39; Mean throughput = 0.014746; Mean flowtime = 0.0000
#
# tote = 59; Entrytime =  4000.1073; Column = 37; Mean throughput = 0.014750; Mean flowtime = 0.0000
#
# tote = 60; Entrytime =  4016.0534; Column = 46; Mean throughput = 0.014940; Mean flowtime = 0.0000
#
# tote = 61; Entrytime =  4076.0735; Column = 12; Mean throughput = 0.014965; Mean flowtime = 0.0000
#
# tote = 62; Entrytime =  4094.0766; Column = 52; Mean throughput = 0.015144; Mean flowtime = 0.0000
#
# tote = 63; Entrytime =  4202.2863; Column =  2; Mean throughput = 0.014992; Mean flowtime = 0.0000
#
# tote = 64; Entrytime =  4256.1457; Column =  5; Mean throughput = 0.015037; Mean flowtime = 0.0000
#
# tote = 65; Entrytime =  4341.2770; Column = 15; Mean throughput = 0.014973; Mean flowtime = 0.0000
#
# tote = 66; Entrytime =  4566.1602; Column = 26; Mean throughput = 0.014454; Mean flowtime = 0.0000
#
# tote = 67; Entrytime =  4636.2744; Column = 34; Mean throughput = 0.014451; Mean flowtime = 0.0000
#
# tote = 68; Entrytime =  4659.2827; Column = 20; Mean throughput = 0.014595; Mean flowtime = 0.0000
#
# tote = 69; Entrytime =  4679.5753; Column = 48; Mean throughput = 0.014745; Mean flowtime = 0.0000
#
# tote = 70; Entrytime =  4817.8019; Column =  9; Mean throughput = 0.014529; Mean flowtime = 0.0000
#
# tote = 71; Entrytime =  4997.4991; Column =  3; Mean throughput = 0.014207; Mean flowtime = 0.0000
#
# tote = 72; Entrytime =  5009.8639; Column =  5; Mean throughput = 0.014372; Mean flowtime = 0.0000
#
# tote = 73; Entrytime =  5038.0330; Column = 19; Mean throughput = 0.014490; Mean flowtime = 0.0000
#
# tote = 74; Entrytime =  5058.0252; Column = 15; Mean throughput = 0.014630; Mean flowtime = 0.0000
#
# tote = 75; Entrytime =  5142.6501; Column = 15; Mean throughput = 0.014584; Mean flowtime = 0.0000
#
# tote = 76; Entrytime =  5423.5940; Column = 10; Mean throughput = 0.014013; Mean flowtime = 0.0000
#
# tote = 77; Entrytime =  5482.2479; Column = 36; Mean throughput = 0.014045; Mean flowtime = 0.0000
#
# tote = 78; Entrytime =  5529.0880; Column = 43; Mean throughput = 0.014107; Mean flowtime = 0.0000
#
# tote = 79; Entrytime =  5530.9859; Column = 31; Mean throughput = 0.014283; Mean flowtime = 0.0000
#
# tote = 80; Entrytime =  5642.0236; Column = 13; Mean throughput = 0.014179; Mean flowtime = 0.0000
#
# tote = 81; Entrytime =  5713.9109; Column = 40; Mean throughput = 0.014176; Mean flowtime = 0.0000
#
# tote = 82; Entrytime =  5728.0793; Column = 30; Mean throughput = 0.014315; Mean flowtime = 0.0000
#
# tote = 83; Entrytime =  5945.4226; Column = 13; Mean throughput = 0.013960; Mean flowtime = 0.0000
#
# tote = 84; Entrytime =  6251.3661; Column = 53; Mean throughput = 0.013437; Mean flowtime = 0.0000
#
# tote = 85; Entrytime =  6310.9484; Column = 14; Mean throughput = 0.013469; Mean flowtime = 0.0000
#
# tote = 86; Entrytime =  6412.3247; Column = 51; Mean throughput = 0.013412; Mean flowtime = 0.0000
#
# tote = 87; Entrytime =  6569.6520; Column = 50; Mean throughput = 0.013243; Mean flowtime = 0.0000
#
# tote = 88; Entrytime =  6650.0385; Column = 37; Mean throughput = 0.013233; Mean flowtime = 0.0000
#
# tote = 89; Entrytime =  6685.7503; Column = 29; Mean throughput = 0.013312; Mean flowtime = 0.0000
#
# tote = 90; Entrytime =  6768.3291; Column = 11; Mean throughput = 0.013297; Mean flowtime = 0.0000
#
# tote = 91; Entrytime =  6810.6829; Column = 15; Mean throughput = 0.013361; Mean flowtime = 0.0000
#
# tote = 92; Entrytime =  6812.3629; Column = 25; Mean throughput = 0.013505; Mean flowtime = 0.0000
#
# tote = 93; Entrytime =  7151.4800; Column =  8; Mean throughput = 0.013004; Mean flowtime = 0.0000
#
# tote = 94; Entrytime =  7153.5474; Column = 29; Mean throughput = 0.013140; Mean flowtime = 0.0000
#
# tote = 95; Entrytime =  7251.2566; Column = 48; Mean throughput = 0.013101; Mean flowtime = 0.0000
#
# tote = 96; Entrytime =  7294.4045; Column = 45; Mean throughput = 0.013161; Mean flowtime = 0.0000
#
# tote = 97; Entrytime =  7299.8853; Column = 26; Mean throughput = 0.013288; Mean flowtime = 0.0000
#
# tote = 98; Entrytime =  7317.3747; Column =  7; Mean throughput = 0.013393; Mean flowtime = 0.0000
#
# tote = 99; Entrytime =  7396.5215; Column = 13; Mean throughput = 0.013385; Mean flowtime = 0.0000
#
# tote = 100; Entrytime =  7419.4538; Column = 38; Mean throughput = 0.013478; Mean flowtime = 0.0000
#
# tote = 101; Entrytime =  7453.6617; Column = 45; Mean throughput = 0.013550; Mean flowtime = 0.0000
#
# tote = 102; Entrytime =  7472.2504; Column = 10; Mean throughput = 0.013651; Mean flowtime = 0.0000
#
# tote = 103; Entrytime =  7481.5513; Column = 11; Mean throughput = 0.013767; Mean flowtime = 0.0000
#
# tote = 104; Entrytime =  7497.7874; Column =  9; Mean throughput = 0.013871; Mean flowtime = 0.0000
#
# tote = 105; Entrytime =  7562.8322; Column = 12; Mean throughput = 0.013884; Mean flowtime = 0.0000
#
# tote = 106; Entrytime =  7598.7800; Column = 54; Mean throughput = 0.013950; Mean flowtime = 0.0000
#
# tote = 107; Entrytime =  7634.1857; Column = 42; Mean throughput = 0.014016; Mean flowtime = 0.0000
#
# tote = 108; Entrytime =  7662.7857; Column = 33; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 109; Entrytime =  7753.5052; Column =  9; Mean throughput = 0.014058; Mean flowtime = 0.0000
#
# tote = 110; Entrytime =  7873.0602; Column = 35; Mean throughput = 0.013972; Mean flowtime = 0.0000
#
# tote = 111; Entrytime =  7895.9478; Column = 48; Mean throughput = 0.014058; Mean flowtime = 0.0000
#
# tote = 112; Entrytime =  8033.0404; Column =  7; Mean throughput = 0.013942; Mean flowtime = 0.0000
#
# tote = 113; Entrytime =  8068.8870; Column = 43; Mean throughput = 0.014004; Mean flowtime = 0.0000
#
# tote = 114; Entrytime =  8092.5059; Column = 22; Mean throughput = 0.014087; Mean flowtime = 0.0000
#
# tote = 115; Entrytime =  8307.0183; Column = 19; Mean throughput = 0.013844; Mean flowtime = 0.0000
#
# tote = 116; Entrytime =  8467.8256; Column = 42; Mean throughput = 0.013699; Mean flowtime = 0.0000
#
# tote = 117; Entrytime =  8573.3367; Column = 53; Mean throughput = 0.013647; Mean flowtime = 0.0000
#
# tote = 118; Entrytime =  8676.8607; Column = 39; Mean throughput = 0.013599; Mean flowtime = 0.0000
#
# tote = 119; Entrytime =  8735.0655; Column = 11; Mean throughput = 0.013623; Mean flowtime = 0.0000
#
# tote = 120; Entrytime =  8858.2498; Column = 42; Mean throughput = 0.013547; Mean flowtime = 0.0000
#
# tote = 121; Entrytime =  9089.0681; Column = 38; Mean throughput = 0.013313; Mean flowtime = 0.0000
#
# tote = 122; Entrytime =  9186.1444; Column = 46; Mean throughput = 0.013281; Mean flowtime = 0.0000
#
# tote = 123; Entrytime =  9208.0126; Column = 10; Mean throughput = 0.013358; Mean flowtime = 0.0000
#
# tote = 124; Entrytime =  9342.7980; Column =  8; Mean throughput = 0.013272; Mean flowtime = 0.0000
#
# tote = 125; Entrytime =  9352.3643; Column =  5; Mean throughput = 0.013366; Mean flowtime = 0.0000
#
# tote = 126; Entrytime =  9409.7259; Column = 46; Mean throughput = 0.013390; Mean flowtime = 0.0000
#
# tote = 127; Entrytime =  9551.6700; Column =  9; Mean throughput = 0.013296; Mean flowtime = 0.0000
#
# tote = 128; Entrytime =  9834.0826; Column = 19; Mean throughput = 0.013016; Mean flowtime = 0.0000
#
# tote = 129; Entrytime =  9845.7532; Column = 14; Mean throughput = 0.013102; Mean flowtime = 0.0000
#
# tote = 130; Entrytime = 10040.4970; Column = 28; Mean throughput = 0.012948; Mean flowtime = 0.0000
#
# tote = 131; Entrytime = 10047.4766; Column = 23; Mean throughput = 0.013038; Mean flowtime = 0.0000
#
# tote = 132; Entrytime = 10218.6482; Column = 17; Mean throughput = 0.012918; Mean flowtime = 0.0000
#
# tote = 133; Entrytime = 10423.3167; Column = 24; Mean throughput = 0.012760; Mean flowtime = 0.0000
#
# tote = 134; Entrytime = 10461.7516; Column = 20; Mean throughput = 0.012809; Mean flowtime = 0.0000
#
# tote = 135; Entrytime = 10468.0578; Column = 52; Mean throughput = 0.012896; Mean flowtime = 0.0000
#
# tote = 136; Entrytime = 10492.5594; Column = 19; Mean throughput = 0.012962; Mean flowtime = 0.0000
#
# tote = 137; Entrytime = 10576.1112; Column = 32; Mean throughput = 0.012954; Mean flowtime = 0.0000
#
# tote = 138; Entrytime = 10580.7321; Column = 46; Mean throughput = 0.013043; Mean flowtime = 0.0000
#
# tote = 139; Entrytime = 10661.0698; Column =  4; Mean throughput = 0.013038; Mean flowtime = 0.0000
#
# tote = 140; Entrytime = 10672.3868; Column = 32; Mean throughput = 0.013118; Mean flowtime = 0.0000
#
# tote = 141; Entrytime = 10674.5451; Column = 24; Mean throughput = 0.013209; Mean flowtime = 0.0000
#
# tote = 142; Entrytime = 10677.7904; Column = 45; Mean throughput = 0.013299; Mean flowtime = 0.0000
#
# tote = 143; Entrytime = 10722.2360; Column = 39; Mean throughput = 0.013337; Mean flowtime = 0.0000
#
# tote = 144; Entrytime = 10916.6860; Column = 51; Mean throughput = 0.013191; Mean flowtime = 0.0000
#
# tote = 145; Entrytime = 10923.1082; Column = 51; Mean throughput = 0.013275; Mean flowtime = 0.0000
#
# tote = 146; Entrytime = 10937.1476; Column = 45; Mean throughput = 0.013349; Mean flowtime = 0.0000
#
# tote = 147; Entrytime = 10971.6170; Column = 53; Mean throughput = 0.013398; Mean flowtime = 0.0000
#
# tote = 148; Entrytime = 10976.0863; Column = 45; Mean throughput = 0.013484; Mean flowtime = 0.0000
#
# tote = 149; Entrytime = 10987.1276; Column = 38; Mean throughput = 0.013561; Mean flowtime = 0.0000
#
# tote = 150; Entrytime = 10995.0099; Column = 25; Mean throughput = 0.013643; Mean flowtime = 0.0000
#
# tote = 151; Entrytime = 11134.5397; Column = 10; Mean throughput = 0.013561; Mean flowtime = 0.0000
#
# tote = 152; Entrytime = 11136.0761; Column = 41; Mean throughput = 0.013649; Mean flowtime = 0.0000
#
# tote = 153; Entrytime = 11145.4048; Column = 52; Mean throughput = 0.013728; Mean flowtime = 0.0000
#
# tote = 154; Entrytime = 11178.3133; Column = 17; Mean throughput = 0.013777; Mean flowtime = 0.0000
#
# tote = 155; Entrytime = 11275.4727; Column = 19; Mean throughput = 0.013747; Mean flowtime = 0.0000
#
# tote = 156; Entrytime = 11334.1216; Column = 22; Mean throughput = 0.013764; Mean flowtime = 0.0000
#
# tote = 157; Entrytime = 11346.7196; Column =  3; Mean throughput = 0.013837; Mean flowtime = 0.0000
#
# tote = 158; Entrytime = 11478.3086; Column = 42; Mean throughput = 0.013765; Mean flowtime = 0.0000
#
# tote = 159; Entrytime = 11500.0652; Column = 37; Mean throughput = 0.013826; Mean flowtime = 0.0000
#
# tote = 160; Entrytime = 11576.7666; Column = 16; Mean throughput = 0.013821; Mean flowtime = 0.0000
#
# tote = 161; Entrytime = 11673.0017; Column =  8; Mean throughput = 0.013793; Mean flowtime = 0.0000
#
# tote = 162; Entrytime = 11868.3228; Column = 35; Mean throughput = 0.013650; Mean flowtime = 0.0000
#
# tote = 163; Entrytime = 11940.6252; Column = 48; Mean throughput = 0.013651; Mean flowtime = 0.0000
#
# tote = 164; Entrytime = 11972.3101; Column = 22; Mean throughput = 0.013698; Mean flowtime = 0.0000
#
# tote = 165; Entrytime = 12017.9802; Column = 31; Mean throughput = 0.013729; Mean flowtime = 0.0000
#
# tote = 166; Entrytime = 12030.0924; Column = 51; Mean throughput = 0.013799; Mean flowtime = 0.0000
#
# tote = 167; Entrytime = 12180.1840; Column = 20; Mean throughput = 0.013711; Mean flowtime = 0.0000
#
# tote = 168; Entrytime = 12208.8359; Column = 36; Mean throughput = 0.013761; Mean flowtime = 0.0000
#
# tote = 169; Entrytime = 12225.9286; Column = 45; Mean throughput = 0.013823; Mean flowtime = 0.0000
#
# tote = 170; Entrytime = 12256.5000; Column = 49; Mean throughput = 0.013870; Mean flowtime = 0.0000
#
# tote = 171; Entrytime = 12267.9521; Column = 47; Mean throughput = 0.013939; Mean flowtime = 0.0000
#
# tote = 172; Entrytime = 12282.1894; Column = 48; Mean throughput = 0.014004; Mean flowtime = 0.0000
#
# tote = 173; Entrytime = 12330.2885; Column = 53; Mean throughput = 0.014030; Mean flowtime = 0.0000
#
# tote = 174; Entrytime = 12395.6856; Column = 10; Mean throughput = 0.014037; Mean flowtime = 0.0000
#
# tote = 175; Entrytime = 12396.5217; Column = 30; Mean throughput = 0.014117; Mean flowtime = 0.0000
#
# tote = 176; Entrytime = 12703.8945; Column = 50; Mean throughput = 0.013854; Mean flowtime = 0.0000
#
# tote = 177; Entrytime = 12867.2915; Column = 49; Mean throughput = 0.013756; Mean flowtime = 0.0000
#
# tote = 178; Entrytime = 12879.7531; Column = 49; Mean throughput = 0.013820; Mean flowtime = 0.0000
#
# tote = 179; Entrytime = 12889.6211; Column = 14; Mean throughput = 0.013887; Mean flowtime = 0.0000
#
# tote = 180; Entrytime = 12906.6336; Column = 18; Mean throughput = 0.013946; Mean flowtime = 0.0000
#
# tote = 181; Entrytime = 12935.6371; Column = 39; Mean throughput = 0.013992; Mean flowtime = 0.0000
#
# tote = 182; Entrytime = 13012.2598; Column = 49; Mean throughput = 0.013987; Mean flowtime = 0.0000
#
# tote = 183; Entrytime = 13161.9323; Column = 35; Mean throughput = 0.013904; Mean flowtime = 0.0000
#
# tote = 184; Entrytime = 13175.9133; Column = 28; Mean throughput = 0.013965; Mean flowtime = 0.0000
#
# tote = 185; Entrytime = 13461.4138; Column = 40; Mean throughput = 0.013743; Mean flowtime = 0.0000
#
# tote = 186; Entrytime = 13510.4327; Column = 32; Mean throughput = 0.013767; Mean flowtime = 0.0000
#
# tote = 187; Entrytime = 13624.2427; Column = 41; Mean throughput = 0.013726; Mean flowtime = 0.0000
#
# tote = 188; Entrytime = 13758.3522; Column =  6; Mean throughput = 0.013664; Mean flowtime = 0.0000
#
# tote = 189; Entrytime = 13764.9849; Column =  1; Mean throughput = 0.013730; Mean flowtime = 0.0000
#
# tote = 190; Entrytime = 13793.3896; Column = 32; Mean throughput = 0.013775; Mean flowtime = 0.0000
#
# tote = 191; Entrytime = 13797.1417; Column = 27; Mean throughput = 0.013843; Mean flowtime = 0.0000
#
# tote = 192; Entrytime = 13850.6832; Column = 21; Mean throughput = 0.013862; Mean flowtime = 0.0000
#
# tote = 193; Entrytime = 13861.4573; Column = 19; Mean throughput = 0.013923; Mean flowtime = 0.0000
#
# tote = 194; Entrytime = 13928.9180; Column = 54; Mean throughput = 0.013928; Mean flowtime = 0.0000
#
# tote = 195; Entrytime = 13939.5383; Column = 48; Mean throughput = 0.013989; Mean flowtime = 0.0000
#
# tote = 196; Entrytime = 13953.9631; Column =  7; Mean throughput = 0.014046; Mean flowtime = 0.0000
#
# tote = 197; Entrytime = 14194.8687; Column = 14; Mean throughput = 0.013878; Mean flowtime = 0.0000
#
# tote = 198; Entrytime = 14205.8425; Column = 35; Mean throughput = 0.013938; Mean flowtime = 0.0000
#
# tote = 199; Entrytime = 14273.7917; Column =  9; Mean throughput = 0.013942; Mean flowtime = 0.0000
#
# tote = 200; Entrytime = 14349.2397; Column = 28; Mean throughput = 0.013938; Mean flowtime = 0.0000
#
# tote = 201; Entrytime = 14375.3607; Column = 25; Mean throughput = 0.013982; Mean flowtime = 0.0000
#
# tote = 202; Entrytime = 14378.7226; Column = 23; Mean throughput = 0.014049; Mean flowtime = 0.0000
#
# tote = 203; Entrytime = 14673.3313; Column = 41; Mean throughput = 0.013835; Mean flowtime = 0.0000
#
# tote = 204; Entrytime = 14785.6942; Column = 22; Mean throughput = 0.013797; Mean flowtime = 0.0000
#
# tote = 205; Entrytime = 14865.2573; Column = 34; Mean throughput = 0.013791; Mean flowtime = 0.0000
#
# tote = 206; Entrytime = 14872.2540; Column = 32; Mean throughput = 0.013851; Mean flowtime = 0.0000
#
# tote = 207; Entrytime = 14929.3214; Column = 14; Mean throughput = 0.013865; Mean flowtime = 0.0000
#
# tote = 208; Entrytime = 14949.4561; Column = 28; Mean throughput = 0.013914; Mean flowtime = 0.0000
#
# tote = 209; Entrytime = 15022.2274; Column = 25; Mean throughput = 0.013913; Mean flowtime = 0.0000
#
# tote = 210; Entrytime = 15087.9312; Column = 25; Mean throughput = 0.013918; Mean flowtime = 0.0000
#
# tote = 211; Entrytime = 15192.9179; Column = 21; Mean throughput = 0.013888; Mean flowtime = 0.0000
#
# tote = 212; Entrytime = 15256.2982; Column = 44; Mean throughput = 0.013896; Mean flowtime = 0.0000
#
# tote = 213; Entrytime = 15324.7585; Column = 45; Mean throughput = 0.013899; Mean flowtime = 0.0000
#
# tote = 214; Entrytime = 15405.7493; Column = 17; Mean throughput = 0.013891; Mean flowtime = 0.0000
#
# tote = 215; Entrytime = 15409.3162; Column = 49; Mean throughput = 0.013953; Mean flowtime = 0.0000
#
# tote = 216; Entrytime = 15423.5961; Column = 13; Mean throughput = 0.014005; Mean flowtime = 0.0000
#
# tote = 217; Entrytime = 15443.9906; Column = 35; Mean throughput = 0.014051; Mean flowtime = 0.0000
#
# tote = 218; Entrytime = 15660.1584; Column = 36; Mean throughput = 0.013921; Mean flowtime = 0.0000
#
# tote = 219; Entrytime = 15757.4421; Column = 51; Mean throughput = 0.013898; Mean flowtime = 0.0000
#
# tote = 220; Entrytime = 15765.0113; Column = 50; Mean throughput = 0.013955; Mean flowtime = 0.0000
#
# tote = 221; Entrytime = 15777.1950; Column = 48; Mean throughput = 0.014008; Mean flowtime = 0.0000
#
# tote = 222; Entrytime = 15790.2068; Column = 34; Mean throughput = 0.014059; Mean flowtime = 0.0000
#
# tote = 223; Entrytime = 15856.5096; Column = 22; Mean throughput = 0.014064; Mean flowtime = 0.0000
#
# tote = 224; Entrytime = 15929.2159; Column = 51; Mean throughput = 0.014062; Mean flowtime = 0.0000
#
# tote = 225; Entrytime = 15944.4859; Column = 31; Mean throughput = 0.014111; Mean flowtime = 0.0000
#
# tote = 226; Entrytime = 15971.7196; Column = 20; Mean throughput = 0.014150; Mean flowtime = 0.0000
#
# tote = 227; Entrytime = 16006.3927; Column = 42; Mean throughput = 0.014182; Mean flowtime = 0.0000
#
# tote = 228; Entrytime = 16026.9980; Column = 53; Mean throughput = 0.014226; Mean flowtime = 0.0000
#
# tote = 229; Entrytime = 16179.3093; Column = 23; Mean throughput = 0.014154; Mean flowtime = 0.0000
#
# tote = 230; Entrytime = 16207.0359; Column = 24; Mean throughput = 0.014191; Mean flowtime = 0.0000
#
# tote = 231; Entrytime = 16208.9763; Column = 12; Mean throughput = 0.014251; Mean flowtime = 0.0000
#
# tote = 232; Entrytime = 16252.1655; Column = 53; Mean throughput = 0.014275; Mean flowtime = 0.0000
#
# tote = 233; Entrytime = 16294.3602; Column = 25; Mean throughput = 0.014299; Mean flowtime = 0.0000
#
# tote = 234; Entrytime = 16385.1845; Column =  3; Mean throughput = 0.014281; Mean flowtime = 0.0000
#
# tote = 235; Entrytime = 16402.4708; Column = 15; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 236; Entrytime = 16493.5644; Column = 47; Mean throughput = 0.014309; Mean flowtime = 0.0000
#
# tote = 237; Entrytime = 16500.7828; Column = 44; Mean throughput = 0.014363; Mean flowtime = 0.0000
#
# tote = 238; Entrytime = 16552.4576; Column = 48; Mean throughput = 0.014379; Mean flowtime = 0.0000
#
# tote = 239; Entrytime = 16564.7477; Column =  6; Mean throughput = 0.014428; Mean flowtime = 0.0000
#
# tote = 240; Entrytime = 16635.5554; Column =  6; Mean throughput = 0.014427; Mean flowtime = 0.0000
#
# tote = 241; Entrytime = 16664.0314; Column = 28; Mean throughput = 0.014462; Mean flowtime = 0.0000
#
# tote = 242; Entrytime = 16672.8297; Column =  6; Mean throughput = 0.014515; Mean flowtime = 0.0000
#
# tote = 243; Entrytime = 16739.0846; Column = 38; Mean throughput = 0.014517; Mean flowtime = 0.0000
#
# tote = 244; Entrytime = 16832.2232; Column = 36; Mean throughput = 0.014496; Mean flowtime = 0.0000
#
# tote = 245; Entrytime = 16956.5943; Column =  9; Mean throughput = 0.014449; Mean flowtime = 0.0000
#
# tote = 246; Entrytime = 16969.1185; Column = 46; Mean throughput = 0.014497; Mean flowtime = 0.0000
#
# tote = 247; Entrytime = 17085.6798; Column = 45; Mean throughput = 0.014457; Mean flowtime = 0.0000
#
# tote = 248; Entrytime = 17127.7973; Column = 30; Mean throughput = 0.014479; Mean flowtime = 0.0000
#
# tote = 249; Entrytime = 17282.1231; Column =  6; Mean throughput = 0.014408; Mean flowtime = 0.0000
#
# tote = 250; Entrytime = 17301.6324; Column = 42; Mean throughput = 0.014450; Mean flowtime = 0.0000
#
# tote = 251; Entrytime = 17326.6343; Column = 15; Mean throughput = 0.014486; Mean flowtime = 0.0000
#
# tote = 252; Entrytime = 17449.1754; Column = 48; Mean throughput = 0.014442; Mean flowtime = 0.0000
#
# tote = 253; Entrytime = 17472.2323; Column = 45; Mean throughput = 0.014480; Mean flowtime = 0.0000
#
# tote = 254; Entrytime = 17522.2786; Column = 28; Mean throughput = 0.014496; Mean flowtime = 0.0000
#
# tote = 255; Entrytime = 17601.4407; Column = 51; Mean throughput = 0.014487; Mean flowtime = 0.0000
#
# tote = 256; Entrytime = 17620.5759; Column = 21; Mean throughput = 0.014528; Mean flowtime = 0.0000
#
# tote = 257; Entrytime = 17646.1237; Column = 52; Mean throughput = 0.014564; Mean flowtime = 0.0000
#
# tote = 258; Entrytime = 17679.5605; Column = 13; Mean throughput = 0.014593; Mean flowtime = 0.0000
#
# tote = 259; Entrytime = 17727.9126; Column = 11; Mean throughput = 0.014610; Mean flowtime = 0.0000
#
# tote = 260; Entrytime = 17794.7917; Column = 13; Mean throughput = 0.014611; Mean flowtime = 0.0000
#
# tote = 261; Entrytime = 17795.2677; Column = 44; Mean throughput = 0.014667; Mean flowtime = 0.0000
#
# tote = 262; Entrytime = 17885.8496; Column =  8; Mean throughput = 0.014648; Mean flowtime = 0.0000
#
# tote = 263; Entrytime = 17898.4865; Column = 44; Mean throughput = 0.014694; Mean flowtime = 0.0000
#
# tote = 264; Entrytime = 18043.4843; Column = 51; Mean throughput = 0.014631; Mean flowtime = 0.0000
#
# tote = 265; Entrytime = 18058.3584; Column = 52; Mean throughput = 0.014675; Mean flowtime = 0.0000
#
# tote = 266; Entrytime = 18079.3402; Column = 46; Mean throughput = 0.014713; Mean flowtime = 0.0000
#
# tote = 267; Entrytime = 18091.0323; Column = 38; Mean throughput = 0.014759; Mean flowtime = 0.0000
#
# tote = 268; Entrytime = 18108.5729; Column =  5; Mean throughput = 0.014800; Mean flowtime = 0.0000
#
# tote = 269; Entrytime = 18181.2601; Column = 30; Mean throughput = 0.014795; Mean flowtime = 0.0000
#
# tote = 270; Entrytime = 18183.3766; Column = 52; Mean throughput = 0.014849; Mean flowtime = 0.0000
#
# tote = 271; Entrytime = 18211.7506; Column = 40; Mean throughput = 0.014881; Mean flowtime = 0.0000
#
# tote = 272; Entrytime = 18253.5709; Column = 37; Mean throughput = 0.014901; Mean flowtime = 0.0000
#
# tote = 273; Entrytime = 18297.8899; Column =  8; Mean throughput = 0.014920; Mean flowtime = 0.0000
#
# tote = 274; Entrytime = 18469.7702; Column = 46; Mean throughput = 0.014835; Mean flowtime = 0.0000
#
# tote = 275; Entrytime = 18521.0156; Column =  1; Mean throughput = 0.014848; Mean flowtime = 0.0000
#
# tote = 276; Entrytime = 18540.6971; Column = 52; Mean throughput = 0.014886; Mean flowtime = 0.0000
#
# tote = 277; Entrytime = 18619.4853; Column = 44; Mean throughput = 0.014877; Mean flowtime = 0.0000
#
# tote = 278; Entrytime = 18700.3213; Column = 42; Mean throughput = 0.014866; Mean flowtime = 0.0000
#
# tote = 279; Entrytime = 18768.9962; Column = 46; Mean throughput = 0.014865; Mean flowtime = 0.0000
#
# tote = 280; Entrytime = 18829.0559; Column = 46; Mean throughput = 0.014871; Mean flowtime = 0.0000
#
# tote = 281; Entrytime = 18838.0539; Column = 25; Mean throughput = 0.014917; Mean flowtime = 0.0000
#
# tote = 282; Entrytime = 18851.8359; Column = 34; Mean throughput = 0.014959; Mean flowtime = 0.0000
#
# tote = 283; Entrytime = 18893.1837; Column = 33; Mean throughput = 0.014979; Mean flowtime = 0.0000
#
# tote = 284; Entrytime = 18950.9156; Column = 33; Mean throughput = 0.014986; Mean flowtime = 0.0000
#
# tote = 285; Entrytime = 19003.9957; Column = 21; Mean throughput = 0.014997; Mean flowtime = 0.0000
#
# tote = 286; Entrytime = 19016.6809; Column = 20; Mean throughput = 0.015039; Mean flowtime = 0.0000
#
# tote = 287; Entrytime = 19133.5253; Column = 26; Mean throughput = 0.015000; Mean flowtime = 0.0000
#
# tote = 288; Entrytime = 19145.6579; Column = 32; Mean throughput = 0.015043; Mean flowtime = 0.0000
#
# tote = 289; Entrytime = 19244.7196; Column = 40; Mean throughput = 0.015017; Mean flowtime = 0.0000
#
# tote = 290; Entrytime = 19245.2818; Column = 24; Mean throughput = 0.015069; Mean flowtime = 0.0000
#
# tote = 291; Entrytime = 19562.3138; Column = 49; Mean throughput = 0.014876; Mean flowtime = 0.0000
#
# tote = 292; Entrytime = 19628.3958; Column = 48; Mean throughput = 0.014876; Mean flowtime = 0.0000
#
# tote = 293; Entrytime = 19720.6374; Column = 19; Mean throughput = 0.014858; Mean flowtime = 0.0000
#
# tote = 294; Entrytime = 19779.7052; Column = 52; Mean throughput = 0.014864; Mean flowtime = 0.0000
#
# tote = 295; Entrytime = 19942.1892; Column = 49; Mean throughput = 0.014793; Mean flowtime = 0.0000
#
# tote = 296; Entrytime = 19985.4692; Column = 10; Mean throughput = 0.014811; Mean flowtime = 0.0000
#
# tote = 297; Entrytime = 19992.7650; Column = 39; Mean throughput = 0.014855; Mean flowtime = 0.0000
#
# tote = 298; Entrytime = 20095.1378; Column = 45; Mean throughput = 0.014829; Mean flowtime = 0.0000
#
# tote = 299; Entrytime = 20288.7427; Column = 32; Mean throughput = 0.014737; Mean flowtime = 0.0000
#
# tote = 300; Entrytime = 20419.2847; Column = 32; Mean throughput = 0.014692; Mean flowtime = 0.0000
#
# tote = 301; Entrytime = 20479.0239; Column = 13; Mean throughput = 0.014698; Mean flowtime = 0.0000
#
# tote = 302; Entrytime = 20483.9073; Column = 37; Mean throughput = 0.014743; Mean flowtime = 0.0000
#
# tote = 303; Entrytime = 20744.4568; Column = 32; Mean throughput = 0.014606; Mean flowtime = 0.0000
#
# tote = 304; Entrytime = 20744.5086; Column = 38; Mean throughput = 0.014654; Mean flowtime = 0.0000
#
# tote = 305; Entrytime = 21073.7551; Column = 36; Mean throughput = 0.014473; Mean flowtime = 0.0000
#
# tote = 306; Entrytime = 21090.8989; Column = 27; Mean throughput = 0.014509; Mean flowtime = 0.0000
#
# tote = 307; Entrytime = 21259.2436; Column = 16; Mean throughput = 0.014441; Mean flowtime = 0.0000
#
# tote = 308; Entrytime = 21301.0842; Column = 21; Mean throughput = 0.014459; Mean flowtime = 0.0000
#
# tote = 309; Entrytime = 21316.1310; Column = 29; Mean throughput = 0.014496; Mean flowtime = 0.0000
#
# tote = 310; Entrytime = 21503.7788; Column = 52; Mean throughput = 0.014416; Mean flowtime = 0.0000
#
# tote = 311; Entrytime = 21591.0133; Column = 50; Mean throughput = 0.014404; Mean flowtime = 0.0000
#
# tote = 312; Entrytime = 21670.2735; Column = 37; Mean throughput = 0.014398; Mean flowtime = 0.0000
#
# tote = 313; Entrytime = 21916.8694; Column = 44; Mean throughput = 0.014281; Mean flowtime = 0.0000
#
# tote = 314; Entrytime = 21986.8866; Column = 12; Mean throughput = 0.014281; Mean flowtime = 0.0000
#
# tote = 315; Entrytime = 22021.9447; Column = 35; Mean throughput = 0.014304; Mean flowtime = 0.0000
#
# tote = 316; Entrytime = 22035.7770; Column = 14; Mean throughput = 0.014340; Mean flowtime = 0.0000
#
# tote = 317; Entrytime = 22058.4451; Column = 23; Mean throughput = 0.014371; Mean flowtime = 0.0000
#
# tote = 318; Entrytime = 22063.5123; Column = 20; Mean throughput = 0.014413; Mean flowtime = 0.0000
#
# tote = 319; Entrytime = 22125.9588; Column = 41; Mean throughput = 0.014417; Mean flowtime = 0.0000
#
# tote = 320; Entrytime = 22244.2300; Column = 34; Mean throughput = 0.014386; Mean flowtime = 0.0000
#
# tote = 321; Entrytime = 22266.9511; Column = 45; Mean throughput = 0.014416; Mean flowtime = 0.0000
#
# tote = 322; Entrytime = 22295.6482; Column = 25; Mean throughput = 0.014442; Mean flowtime = 0.0000
#
# tote = 323; Entrytime = 22342.3547; Column =  2; Mean throughput = 0.014457; Mean flowtime = 0.0000
#
# tote = 324; Entrytime = 22371.0285; Column =  5; Mean throughput = 0.014483; Mean flowtime = 0.0000
#
# tote = 325; Entrytime = 22525.8882; Column = 12; Mean throughput = 0.014428; Mean flowtime = 0.0000
#
# tote = 326; Entrytime = 22760.8203; Column = 24; Mean throughput = 0.014323; Mean flowtime = 0.0000
#
# tote = 327; Entrytime = 22911.0656; Column =  8; Mean throughput = 0.014273; Mean flowtime = 0.0000
#
# tote = 328; Entrytime = 22925.4660; Column = 20; Mean throughput = 0.014307; Mean flowtime = 0.0000
#
# tote = 329; Entrytime = 22985.0007; Column = 33; Mean throughput = 0.014314; Mean flowtime = 0.0000
#
# tote = 330; Entrytime = 23119.0628; Column = 46; Mean throughput = 0.014274; Mean flowtime = 0.0000
#
# tote = 331; Entrytime = 23150.4209; Column = 17; Mean throughput = 0.014298; Mean flowtime = 0.0000
#
# tote = 332; Entrytime = 23308.7235; Column = 54; Mean throughput = 0.014244; Mean flowtime = 0.0000
#
# tote = 333; Entrytime = 23373.7952; Column =  2; Mean throughput = 0.014247; Mean flowtime = 0.0000
#
# tote = 334; Entrytime = 23448.5230; Column = 51; Mean throughput = 0.014244; Mean flowtime = 0.0000
#
# tote = 335; Entrytime = 23534.7467; Column = 47; Mean throughput = 0.014234; Mean flowtime = 0.0000
#
# tote = 336; Entrytime = 23552.4917; Column =  2; Mean throughput = 0.014266; Mean flowtime = 0.0000
#
# tote = 337; Entrytime = 23638.8028; Column =  6; Mean throughput = 0.014256; Mean flowtime = 0.0000
#
# tote = 338; Entrytime = 23767.4251; Column = 38; Mean throughput = 0.014221; Mean flowtime = 0.0000
#
# tote = 339; Entrytime = 23901.6666; Column = 28; Mean throughput = 0.014183; Mean flowtime = 0.0000
#
# tote = 340; Entrytime = 24017.3824; Column = 51; Mean throughput = 0.014156; Mean flowtime = 0.0000
#
# tote = 341; Entrytime = 24022.3526; Column = 15; Mean throughput = 0.014195; Mean flowtime = 0.0000
#
# tote = 342; Entrytime = 24032.4202; Column = 39; Mean throughput = 0.014231; Mean flowtime = 0.0000
#
# tote = 343; Entrytime = 24142.6612; Column = 24; Mean throughput = 0.014207; Mean flowtime = 0.0000
#
# tote = 344; Entrytime = 24268.0953; Column =  9; Mean throughput = 0.014175; Mean flowtime = 0.0000
#
# tote = 345; Entrytime = 24295.5903; Column = 11; Mean throughput = 0.014200; Mean flowtime = 0.0000
#
# tote = 346; Entrytime = 24315.2985; Column = 19; Mean throughput = 0.014230; Mean flowtime = 0.0000
#
# tote = 347; Entrytime = 24319.8367; Column =  9; Mean throughput = 0.014268; Mean flowtime = 0.0000
#
# tote = 348; Entrytime = 24635.8055; Column = 50; Mean throughput = 0.014126; Mean flowtime = 0.0000
#
# tote = 349; Entrytime = 24646.3811; Column =  7; Mean throughput = 0.014160; Mean flowtime = 0.0000
#
# tote = 350; Entrytime = 24682.5848; Column = 33; Mean throughput = 0.014180; Mean flowtime = 0.0000
#
# tote = 351; Entrytime = 24794.5720; Column = 41; Mean throughput = 0.014156; Mean flowtime = 0.0000
#
# tote = 352; Entrytime = 24929.1166; Column = 35; Mean throughput = 0.014120; Mean flowtime = 0.0000
#
# tote = 353; Entrytime = 25135.0149; Column = 31; Mean throughput = 0.014044; Mean flowtime = 0.0000
#
# tote = 354; Entrytime = 25164.1876; Column =  7; Mean throughput = 0.014068; Mean flowtime = 0.0000
#
# tote = 355; Entrytime = 25212.4550; Column = 37; Mean throughput = 0.014080; Mean flowtime = 0.0000
#
# tote = 356; Entrytime = 25235.2839; Column = 31; Mean throughput = 0.014107; Mean flowtime = 0.0000
#
# tote = 357; Entrytime = 25265.1087; Column = 19; Mean throughput = 0.014130; Mean flowtime = 0.0000
#
# tote = 358; Entrytime = 25331.0350; Column =  1; Mean throughput = 0.014133; Mean flowtime = 0.0000
#
# tote = 359; Entrytime = 25443.0458; Column =  8; Mean throughput = 0.014110; Mean flowtime = 0.0000
#
# tote = 360; Entrytime = 25485.3024; Column = 54; Mean throughput = 0.014126; Mean flowtime = 0.0000
#
# tote = 361; Entrytime = 25522.5799; Column = 18; Mean throughput = 0.014144; Mean flowtime = 0.0000
#
# tote = 362; Entrytime = 25540.1022; Column = 27; Mean throughput = 0.014174; Mean flowtime = 0.0000
#
# tote = 363; Entrytime = 25581.4076; Column = 51; Mean throughput = 0.014190; Mean flowtime = 0.0000
#
# tote = 364; Entrytime = 25767.6511; Column = 48; Mean throughput = 0.014126; Mean flowtime = 0.0000
#
# tote = 365; Entrytime = 25768.0876; Column = 36; Mean throughput = 0.014165; Mean flowtime = 0.0000
#
# tote = 366; Entrytime = 25816.1800; Column =  4; Mean throughput = 0.014177; Mean flowtime = 0.0000
#
# tote = 367; Entrytime = 25825.5083; Column = 46; Mean throughput = 0.014211; Mean flowtime = 0.0000
#
# tote = 368; Entrytime = 25849.4035; Column = 54; Mean throughput = 0.014236; Mean flowtime = 0.0000
#
# tote = 369; Entrytime = 25849.5352; Column = 26; Mean throughput = 0.014275; Mean flowtime = 0.0000
#
# tote = 370; Entrytime = 26069.2333; Column = 37; Mean throughput = 0.014193; Mean flowtime = 0.0000
#
# tote = 371; Entrytime = 26095.8621; Column = 43; Mean throughput = 0.014217; Mean flowtime = 0.0000
#
# tote = 372; Entrytime = 26177.4330; Column = 16; Mean throughput = 0.014211; Mean flowtime = 0.0000
#
# tote = 373; Entrytime = 26269.3266; Column = 41; Mean throughput = 0.014199; Mean flowtime = 0.0000
#
# tote = 374; Entrytime = 26418.0172; Column =  3; Mean throughput = 0.014157; Mean flowtime = 0.0000
#
# tote = 375; Entrytime = 26463.7211; Column = 45; Mean throughput = 0.014170; Mean flowtime = 0.0000
#
# tote = 376; Entrytime = 26499.8030; Column = 43; Mean throughput = 0.014189; Mean flowtime = 0.0000
#
# tote = 377; Entrytime = 26528.3396; Column = 19; Mean throughput = 0.014211; Mean flowtime = 0.0000
#
# tote = 378; Entrytime = 26587.5537; Column = 18; Mean throughput = 0.014217; Mean flowtime = 0.0000
#
# tote = 379; Entrytime = 26687.7645; Column = 38; Mean throughput = 0.014201; Mean flowtime = 0.0000
#
# tote = 380; Entrytime = 26851.9923; Column = 48; Mean throughput = 0.014152; Mean flowtime = 0.0000
#
# tote = 381; Entrytime = 26853.4342; Column = 46; Mean throughput = 0.014188; Mean flowtime = 0.0000
#
# tote = 382; Entrytime = 26897.9945; Column = 47; Mean throughput = 0.014202; Mean flowtime = 0.0000
#
# tote = 383; Entrytime = 27008.1926; Column =  1; Mean throughput = 0.014181; Mean flowtime = 0.0000
#
# tote = 384; Entrytime = 27012.6542; Column =  1; Mean throughput = 0.014216; Mean flowtime = 0.0000
#
# tote = 385; Entrytime = 27141.3170; Column = 41; Mean throughput = 0.014185; Mean flowtime = 0.0000
#
# tote = 386; Entrytime = 27174.5072; Column = 20; Mean throughput = 0.014204; Mean flowtime = 0.0000
#
# tote = 387; Entrytime = 27192.2549; Column = 17; Mean throughput = 0.014232; Mean flowtime = 0.0000
#
# tote = 388; Entrytime = 27345.4418; Column = 17; Mean throughput = 0.014189; Mean flowtime = 0.0000
#
# tote = 389; Entrytime = 27348.8535; Column = 24; Mean throughput = 0.014224; Mean flowtime = 0.0000
#
# tote = 390; Entrytime = 27378.9675; Column = 11; Mean throughput = 0.014245; Mean flowtime = 0.0000
#
# tote = 391; Entrytime = 27409.4165; Column = 54; Mean throughput = 0.014265; Mean flowtime = 0.0000
#
# tote = 392; Entrytime = 27451.5617; Column = 29; Mean throughput = 0.014280; Mean flowtime = 0.0000
#
# tote = 393; Entrytime = 27494.2318; Column = 46; Mean throughput = 0.014294; Mean flowtime = 0.0000
#
# tote = 394; Entrytime = 27503.5691; Column =  8; Mean throughput = 0.014325; Mean flowtime = 0.0000
#
# tote = 395; Entrytime = 27541.9530; Column =  8; Mean throughput = 0.014342; Mean flowtime = 0.0000
#
# tote = 396; Entrytime = 27566.5039; Column = 24; Mean throughput = 0.014365; Mean flowtime = 0.0000
#
# tote = 397; Entrytime = 27655.3495; Column = 45; Mean throughput = 0.014355; Mean flowtime = 0.0000
#
# tote = 398; Entrytime = 27657.6625; Column = 51; Mean throughput = 0.014390; Mean flowtime = 0.0000
#
# tote = 399; Entrytime = 27742.7570; Column = 28; Mean throughput = 0.014382; Mean flowtime = 0.0000
#
# tote = 400; Entrytime = 27763.7407; Column = 40; Mean throughput = 0.014407; Mean flowtime = 0.0000
#
# tote = 401; Entrytime = 27911.4017; Column =  6; Mean throughput = 0.014367; Mean flowtime = 0.0000
#
# tote = 402; Entrytime = 28002.8728; Column =  4; Mean throughput = 0.014356; Mean flowtime = 0.0000
#
# tote = 403; Entrytime = 28261.6891; Column = 19; Mean throughput = 0.014260; Mean flowtime = 0.0000
#
# tote = 404; Entrytime = 28284.7325; Column = 42; Mean throughput = 0.014283; Mean flowtime = 0.0000
#
# tote = 405; Entrytime = 28352.6409; Column = 22; Mean throughput = 0.014284; Mean flowtime = 0.0000
#
# tote = 406; Entrytime = 28376.7034; Column = 28; Mean throughput = 0.014308; Mean flowtime = 0.0000
#
# tote = 407; Entrytime = 28422.1279; Column = 21; Mean throughput = 0.014320; Mean flowtime = 0.0000
#
# tote = 408; Entrytime = 28470.3099; Column = 29; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 409; Entrytime = 28471.7376; Column =  7; Mean throughput = 0.014365; Mean flowtime = 0.0000
#
# tote = 410; Entrytime = 28488.9107; Column = 13; Mean throughput = 0.014392; Mean flowtime = 0.0000
#
# tote = 411; Entrytime = 28663.7023; Column = 22; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 412; Entrytime = 28689.0261; Column = 53; Mean throughput = 0.014361; Mean flowtime = 0.0000
#
# tote = 413; Entrytime = 28706.5416; Column = 29; Mean throughput = 0.014387; Mean flowtime = 0.0000
#
# tote = 414; Entrytime = 28735.0208; Column =  1; Mean throughput = 0.014408; Mean flowtime = 0.0000
#
# tote = 415; Entrytime = 28787.2862; Column =  3; Mean throughput = 0.014416; Mean flowtime = 0.0000
#
# tote = 416; Entrytime = 28819.9732; Column = 15; Mean throughput = 0.014434; Mean flowtime = 0.0000
#
# tote = 417; Entrytime = 28873.4423; Column = 34; Mean throughput = 0.014442; Mean flowtime = 0.0000
#
# tote = 418; Entrytime = 28875.5139; Column = 38; Mean throughput = 0.014476; Mean flowtime = 0.0000
#
# tote = 419; Entrytime = 28883.7916; Column = 33; Mean throughput = 0.014506; Mean flowtime = 0.0000
#
# tote = 420; Entrytime = 28996.6160; Column = 15; Mean throughput = 0.014484; Mean flowtime = 0.0000
#
# tote = 421; Entrytime = 29359.8347; Column = 21; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 422; Entrytime = 29403.6463; Column = 26; Mean throughput = 0.014352; Mean flowtime = 0.0000
#
# tote = 423; Entrytime = 29472.3743; Column = 15; Mean throughput = 0.014352; Mean flowtime = 0.0000
#
# tote = 424; Entrytime = 29476.5545; Column = 53; Mean throughput = 0.014384; Mean flowtime = 0.0000
#
# tote = 425; Entrytime = 29502.2412; Column = 34; Mean throughput = 0.014406; Mean flowtime = 0.0000
#
# tote = 426; Entrytime = 29730.0641; Column = 18; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 427; Entrytime = 29845.8824; Column = 20; Mean throughput = 0.014307; Mean flowtime = 0.0000
#
# tote = 428; Entrytime = 29858.5213; Column =  4; Mean throughput = 0.014334; Mean flowtime = 0.0000
#
# tote = 429; Entrytime = 29941.0005; Column = 45; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 430; Entrytime = 30035.8571; Column =  7; Mean throughput = 0.014316; Mean flowtime = 0.0000
#
# tote = 431; Entrytime = 30106.9290; Column = 43; Mean throughput = 0.014316; Mean flowtime = 0.0000
#
# tote = 432; Entrytime = 30231.6643; Column = 41; Mean throughput = 0.014290; Mean flowtime = 0.0000
#
# tote = 433; Entrytime = 30290.3211; Column = 37; Mean throughput = 0.014295; Mean flowtime = 0.0000
#
# tote = 434; Entrytime = 30322.7479; Column =  8; Mean throughput = 0.014313; Mean flowtime = 0.0000
#
# tote = 435; Entrytime = 30375.7494; Column =  9; Mean throughput = 0.014321; Mean flowtime = 0.0000
#
# tote = 436; Entrytime = 30423.0178; Column = 19; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 437; Entrytime = 30550.6716; Column = 17; Mean throughput = 0.014304; Mean flowtime = 0.0000
#
# tote = 438; Entrytime = 30568.9563; Column = 46; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 439; Entrytime = 30665.1778; Column = 23; Mean throughput = 0.014316; Mean flowtime = 0.0000
#
# tote = 440; Entrytime = 30859.8403; Column =  1; Mean throughput = 0.014258; Mean flowtime = 0.0000
#
# tote = 441; Entrytime = 30954.2029; Column =  3; Mean throughput = 0.014247; Mean flowtime = 0.0000
#
# tote = 442; Entrytime = 30955.0498; Column = 47; Mean throughput = 0.014279; Mean flowtime = 0.0000
#
# tote = 443; Entrytime = 30964.5015; Column = 18; Mean throughput = 0.014307; Mean flowtime = 0.0000
#
# tote = 444; Entrytime = 31030.0066; Column =  7; Mean throughput = 0.014309; Mean flowtime = 0.0000
#
# tote = 445; Entrytime = 31183.6867; Column = 33; Mean throughput = 0.014270; Mean flowtime = 0.0000
#
# tote = 446; Entrytime = 31287.8371; Column = 49; Mean throughput = 0.014255; Mean flowtime = 0.0000
#
# tote = 447; Entrytime = 31408.3490; Column = 48; Mean throughput = 0.014232; Mean flowtime = 0.0000
#
# tote = 448; Entrytime = 31437.5040; Column =  6; Mean throughput = 0.014250; Mean flowtime = 0.0000
#
# tote = 449; Entrytime = 31445.0691; Column = 12; Mean throughput = 0.014279; Mean flowtime = 0.0000
#
# tote = 450; Entrytime = 31507.0836; Column = 53; Mean throughput = 0.014283; Mean flowtime = 0.0000
#
# tote = 451; Entrytime = 31509.8270; Column =  5; Mean throughput = 0.014313; Mean flowtime = 0.0000
#
# tote = 452; Entrytime = 31569.3721; Column = 35; Mean throughput = 0.014318; Mean flowtime = 0.0000
#
# tote = 453; Entrytime = 31696.9779; Column = 19; Mean throughput = 0.014292; Mean flowtime = 0.0000
#
# tote = 454; Entrytime = 31806.4004; Column = 47; Mean throughput = 0.014274; Mean flowtime = 0.0000
#
# tote = 455; Entrytime = 31858.6173; Column = 13; Mean throughput = 0.014282; Mean flowtime = 0.0000
#
# tote = 456; Entrytime = 32045.0269; Column = 18; Mean throughput = 0.014230; Mean flowtime = 0.0000
#
# tote = 457; Entrytime = 32178.6695; Column = 24; Mean throughput = 0.014202; Mean flowtime = 0.0000
#
# tote = 458; Entrytime = 32185.6327; Column = 40; Mean throughput = 0.014230; Mean flowtime = 0.0000
#
# tote = 459; Entrytime = 32227.5972; Column = 20; Mean throughput = 0.014242; Mean flowtime = 0.0000
#
# tote = 460; Entrytime = 32251.2580; Column = 35; Mean throughput = 0.014263; Mean flowtime = 0.0000
#
# tote = 461; Entrytime = 32253.9510; Column = 14; Mean throughput = 0.014293; Mean flowtime = 0.0000
#
# tote = 462; Entrytime = 32295.4698; Column = 43; Mean throughput = 0.014305; Mean flowtime = 0.0000
#
# tote = 463; Entrytime = 32338.0272; Column = 44; Mean throughput = 0.014318; Mean flowtime = 0.0000
#
# tote = 464; Entrytime = 32546.5193; Column = 11; Mean throughput = 0.014257; Mean flowtime = 0.0000
#
# tote = 465; Entrytime = 32594.9778; Column = 37; Mean throughput = 0.014266; Mean flowtime = 0.0000
#
# tote = 466; Entrytime = 32612.3868; Column = 41; Mean throughput = 0.014289; Mean flowtime = 0.0000
#
# tote = 467; Entrytime = 32797.7540; Column = 54; Mean throughput = 0.014239; Mean flowtime = 0.0000
#
# tote = 468; Entrytime = 32910.2137; Column = 25; Mean throughput = 0.014221; Mean flowtime = 0.0000
#
# tote = 469; Entrytime = 33017.2441; Column = 47; Mean throughput = 0.014205; Mean flowtime = 0.0000
#
# tote = 470; Entrytime = 33021.8385; Column = 23; Mean throughput = 0.014233; Mean flowtime = 0.0000
#
# tote = 471; Entrytime = 33057.3673; Column = 53; Mean throughput = 0.014248; Mean flowtime = 0.0000
#
# tote = 472; Entrytime = 33095.1739; Column = 29; Mean throughput = 0.014262; Mean flowtime = 0.0000
#
# tote = 473; Entrytime = 33150.1228; Column = 50; Mean throughput = 0.014268; Mean flowtime = 0.0000
#
# tote = 474; Entrytime = 33306.3455; Column = 28; Mean throughput = 0.014232; Mean flowtime = 0.0000
#
# tote = 475; Entrytime = 33342.7689; Column = 52; Mean throughput = 0.014246; Mean flowtime = 0.0000
#
# tote = 476; Entrytime = 33434.8019; Column =  1; Mean throughput = 0.014237; Mean flowtime = 0.0000
#
# ...
#
# tote = 9846; Entrytime = 686746.9776; Column = 47; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9847; Entrytime = 686921.9812; Column = 22; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9848; Entrytime = 686985.1747; Column = 19; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9849; Entrytime = 686989.8775; Column = 14; Mean throughput = 0.014336; Mean flowtime = 0.0000
#
# tote = 9850; Entrytime = 687034.1116; Column = 26; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9851; Entrytime = 687103.2852; Column = 50; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9852; Entrytime = 687118.9243; Column = 14; Mean throughput = 0.014338; Mean flowtime = 0.0000
#
# tote = 9853; Entrytime = 687323.9212; Column = 19; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9854; Entrytime = 687342.3977; Column = 52; Mean throughput = 0.014336; Mean flowtime = 0.0000
#
# tote = 9855; Entrytime = 687401.0909; Column = 36; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9856; Entrytime = 687428.0985; Column = 45; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9857; Entrytime = 687641.3622; Column = 49; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9858; Entrytime = 687750.2941; Column = 51; Mean throughput = 0.014334; Mean flowtime = 0.0000
#
# tote = 9859; Entrytime = 687780.5484; Column =  2; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9860; Entrytime = 687920.0432; Column = 48; Mean throughput = 0.014333; Mean flowtime = 0.0000
#
# tote = 9861; Entrytime = 688186.3666; Column = 12; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9862; Entrytime = 688196.0268; Column = 26; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9863; Entrytime = 688383.6695; Column = 41; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9864; Entrytime = 688451.7690; Column =  9; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9865; Entrytime = 688479.6243; Column = 35; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9866; Entrytime = 688514.9417; Column = 11; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9867; Entrytime = 688612.0271; Column = 52; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9868; Entrytime = 688707.0533; Column = 39; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9869; Entrytime = 688725.2570; Column = 31; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9870; Entrytime = 688765.3022; Column = 42; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9871; Entrytime = 688767.2173; Column = 23; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 9872; Entrytime = 688966.2204; Column = 42; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9873; Entrytime = 689008.7933; Column = 29; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9874; Entrytime = 689082.8143; Column = 16; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9875; Entrytime = 689106.2019; Column = 43; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9876; Entrytime = 689131.0976; Column = 32; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 9877; Entrytime = 689237.9622; Column = 33; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9878; Entrytime = 689343.8721; Column = 42; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9879; Entrytime = 689381.8284; Column = 45; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9880; Entrytime = 689517.9720; Column = 17; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9881; Entrytime = 689598.0824; Column = 28; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9882; Entrytime = 689667.9730; Column = 32; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9883; Entrytime = 689669.0647; Column = 22; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9884; Entrytime = 689693.2768; Column = 36; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 9885; Entrytime = 689948.5884; Column =  5; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9886; Entrytime = 690017.9819; Column =  6; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9887; Entrytime = 690061.0454; Column = 31; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9888; Entrytime = 690315.0806; Column =  8; Mean throughput = 0.014324; Mean flowtime = 0.0000
#
# tote = 9889; Entrytime = 690385.0662; Column = 12; Mean throughput = 0.014324; Mean flowtime = 0.0000
#
# tote = 9890; Entrytime = 690388.7874; Column = 50; Mean throughput = 0.014325; Mean flowtime = 0.0000
#
# tote = 9891; Entrytime = 690567.9781; Column = 18; Mean throughput = 0.014323; Mean flowtime = 0.0000
#
# tote = 9892; Entrytime = 690609.3307; Column = 29; Mean throughput = 0.014324; Mean flowtime = 0.0000
#
# tote = 9893; Entrytime = 690741.8563; Column = 24; Mean throughput = 0.014322; Mean flowtime = 0.0000
#
# tote = 9894; Entrytime = 690864.6660; Column = 38; Mean throughput = 0.014321; Mean flowtime = 0.0000
#
# tote = 9895; Entrytime = 690993.2255; Column = 37; Mean throughput = 0.014320; Mean flowtime = 0.0000
#
# tote = 9896; Entrytime = 691026.6848; Column = 41; Mean throughput = 0.014321; Mean flowtime = 0.0000
#
# tote = 9897; Entrytime = 691091.5101; Column = 47; Mean throughput = 0.014321; Mean flowtime = 0.0000
#
# tote = 9898; Entrytime = 691144.3841; Column = 31; Mean throughput = 0.014321; Mean flowtime = 0.0000
#
# tote = 9899; Entrytime = 691151.7784; Column = 44; Mean throughput = 0.014322; Mean flowtime = 0.0000
#
# tote = 9900; Entrytime = 691159.5335; Column = 52; Mean throughput = 0.014324; Mean flowtime = 0.0000
#
# tote = 9901; Entrytime = 691167.2680; Column = 45; Mean throughput = 0.014325; Mean flowtime = 0.0000
#
# tote = 9902; Entrytime = 691168.0181; Column = 26; Mean throughput = 0.014326; Mean flowtime = 0.0000
#
# tote = 9903; Entrytime = 691192.8887; Column = 25; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9904; Entrytime = 691225.1258; Column = 26; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9905; Entrytime = 691234.1244; Column = 52; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9906; Entrytime = 691483.4790; Column = 43; Mean throughput = 0.014326; Mean flowtime = 0.0000
#
# tote = 9907; Entrytime = 691509.8772; Column =  6; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9908; Entrytime = 691534.8300; Column = 17; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9909; Entrytime = 691579.9980; Column = 38; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9910; Entrytime = 691606.7065; Column = 49; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9911; Entrytime = 691740.2196; Column = 31; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9912; Entrytime = 691797.8822; Column =  8; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9913; Entrytime = 691886.0819; Column = 38; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9914; Entrytime = 692041.9807; Column =  8; Mean throughput = 0.014326; Mean flowtime = 0.0000
#
# tote = 9915; Entrytime = 692062.4641; Column =  2; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9916; Entrytime = 692081.2543; Column = 54; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9917; Entrytime = 692165.6597; Column = 54; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9918; Entrytime = 692296.7630; Column = 51; Mean throughput = 0.014326; Mean flowtime = 0.0000
#
# tote = 9919; Entrytime = 692336.6269; Column = 49; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9920; Entrytime = 692344.1581; Column = 11; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9921; Entrytime = 692384.3710; Column = 13; Mean throughput = 0.014329; Mean flowtime = 0.0000
#
# tote = 9922; Entrytime = 692519.1800; Column = 52; Mean throughput = 0.014327; Mean flowtime = 0.0000
#
# tote = 9923; Entrytime = 692553.4310; Column =  8; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9924; Entrytime = 692608.4591; Column = 35; Mean throughput = 0.014328; Mean flowtime = 0.0000
#
# tote = 9925; Entrytime = 692613.3991; Column = 40; Mean throughput = 0.014330; Mean flowtime = 0.0000
#
# tote = 9926; Entrytime = 692631.3564; Column = 30; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 9927; Entrytime = 692684.1041; Column =  5; Mean throughput = 0.014331; Mean flowtime = 0.0000
#
# tote = 9928; Entrytime = 692684.5940; Column = 15; Mean throughput = 0.014333; Mean flowtime = 0.0000
#
# tote = 9929; Entrytime = 692768.5298; Column = 46; Mean throughput = 0.014332; Mean flowtime = 0.0000
#
# tote = 9930; Entrytime = 692835.6544; Column =  4; Mean throughput = 0.014332; Mean flowtime = 0.0000
#
# tote = 9931; Entrytime = 692836.6305; Column = 50; Mean throughput = 0.014334; Mean flowtime = 0.0000
#
# tote = 9932; Entrytime = 692879.4025; Column = 28; Mean throughput = 0.014334; Mean flowtime = 0.0000
#
# tote = 9933; Entrytime = 692925.5471; Column = 45; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9934; Entrytime = 692968.7870; Column = 28; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9935; Entrytime = 693087.5679; Column = 26; Mean throughput = 0.014334; Mean flowtime = 0.0000
#
# tote = 9936; Entrytime = 693123.6579; Column = 29; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9937; Entrytime = 693185.6836; Column =  5; Mean throughput = 0.014335; Mean flowtime = 0.0000
#
# tote = 9938; Entrytime = 693189.7293; Column = 38; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9939; Entrytime = 693282.2550; Column = 33; Mean throughput = 0.014336; Mean flowtime = 0.0000
#
# tote = 9940; Entrytime = 693348.2044; Column = 18; Mean throughput = 0.014336; Mean flowtime = 0.0000
#
# tote = 9941; Entrytime = 693406.3298; Column = 11; Mean throughput = 0.014336; Mean flowtime = 0.0000
#
# tote = 9942; Entrytime = 693469.5686; Column = 23; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9943; Entrytime = 693496.8061; Column = 54; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9944; Entrytime = 693597.3012; Column =  8; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9945; Entrytime = 693649.7505; Column = 25; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9946; Entrytime = 693669.8167; Column = 50; Mean throughput = 0.014338; Mean flowtime = 0.0000
#
# tote = 9947; Entrytime = 693819.7094; Column = 11; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9948; Entrytime = 693843.4217; Column = 36; Mean throughput = 0.014338; Mean flowtime = 0.0000
#
# tote = 9949; Entrytime = 693849.4834; Column =  7; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 9950; Entrytime = 693936.5220; Column =  1; Mean throughput = 0.014338; Mean flowtime = 0.0000
#
# tote = 9951; Entrytime = 693939.2664; Column = 25; Mean throughput = 0.014340; Mean flowtime = 0.0000
#
# tote = 9952; Entrytime = 693956.4686; Column = 34; Mean throughput = 0.014341; Mean flowtime = 0.0000
#
# tote = 9953; Entrytime = 694043.1254; Column = 53; Mean throughput = 0.014341; Mean flowtime = 0.0000
#
# tote = 9954; Entrytime = 694053.3772; Column = 43; Mean throughput = 0.014342; Mean flowtime = 0.0000
#
# tote = 9955; Entrytime = 694088.8699; Column = 26; Mean throughput = 0.014343; Mean flowtime = 0.0000
#
# tote = 9956; Entrytime = 694095.4413; Column =  3; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9957; Entrytime = 694108.2316; Column =  6; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9958; Entrytime = 694182.2791; Column = 39; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9959; Entrytime = 694215.0348; Column = 45; Mean throughput = 0.014346; Mean flowtime = 0.0000
#
# tote = 9960; Entrytime = 694295.3164; Column = 39; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9961; Entrytime = 694312.1203; Column =  3; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9962; Entrytime = 694390.0387; Column = 46; Mean throughput = 0.014346; Mean flowtime = 0.0000
#
# tote = 9963; Entrytime = 694433.2789; Column = 15; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9964; Entrytime = 694555.1481; Column = 49; Mean throughput = 0.014346; Mean flowtime = 0.0000
#
# tote = 9965; Entrytime = 694555.9483; Column = 19; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9966; Entrytime = 694653.9567; Column = 25; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9967; Entrytime = 694677.2493; Column =  6; Mean throughput = 0.014348; Mean flowtime = 0.0000
#
# tote = 9968; Entrytime = 694934.6414; Column = 50; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9969; Entrytime = 694971.4392; Column = 22; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9970; Entrytime = 694975.7877; Column = 31; Mean throughput = 0.014346; Mean flowtime = 0.0000
#
# tote = 9971; Entrytime = 695010.9827; Column = 41; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9972; Entrytime = 695021.4322; Column =  9; Mean throughput = 0.014348; Mean flowtime = 0.0000
#
# tote = 9973; Entrytime = 695038.3362; Column =  8; Mean throughput = 0.014349; Mean flowtime = 0.0000
#
# tote = 9974; Entrytime = 695196.7184; Column = 52; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9975; Entrytime = 695204.4005; Column = 15; Mean throughput = 0.014348; Mean flowtime = 0.0000
#
# tote = 9976; Entrytime = 695547.4292; Column = 38; Mean throughput = 0.014343; Mean flowtime = 0.0000
#
# tote = 9977; Entrytime = 695560.3664; Column = 37; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9978; Entrytime = 695573.1907; Column = 38; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9979; Entrytime = 695645.4301; Column = 26; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9980; Entrytime = 695724.5922; Column = 13; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9981; Entrytime = 695873.4667; Column =  2; Mean throughput = 0.014343; Mean flowtime = 0.0000
#
# tote = 9982; Entrytime = 695886.8584; Column = 35; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9983; Entrytime = 695910.7759; Column = 25; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9984; Entrytime = 695927.2552; Column = 41; Mean throughput = 0.014346; Mean flowtime = 0.0000
#
# tote = 9985; Entrytime = 695965.4045; Column = 13; Mean throughput = 0.014347; Mean flowtime = 0.0000
#
# tote = 9986; Entrytime = 695991.6807; Column = 31; Mean throughput = 0.014348; Mean flowtime = 0.0000
#
# tote = 9987; Entrytime = 696198.6917; Column =  5; Mean throughput = 0.014345; Mean flowtime = 0.0000
#
# tote = 9988; Entrytime = 696374.8320; Column = 48; Mean throughput = 0.014343; Mean flowtime = 0.0000
#
# tote = 9989; Entrytime = 696461.8851; Column = 27; Mean throughput = 0.014342; Mean flowtime = 0.0000
#
# tote = 9990; Entrytime = 696516.0259; Column = 22; Mean throughput = 0.014343; Mean flowtime = 0.0000
#
# tote = 9991; Entrytime = 696537.4360; Column = 35; Mean throughput = 0.014344; Mean flowtime = 0.0000
#
# tote = 9992; Entrytime = 696907.3260; Column = 48; Mean throughput = 0.014338; Mean flowtime = 0.0000
#
# tote = 9993; Entrytime = 696930.0561; Column = 49; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 9994; Entrytime = 696986.5579; Column = 11; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 9995; Entrytime = 696992.2990; Column = 38; Mean throughput = 0.014340; Mean flowtime = 0.0000
#
# tote = 9996; Entrytime = 697104.2158; Column = 30; Mean throughput = 0.014339; Mean flowtime = 0.0000
#
# tote = 9997; Entrytime = 697271.2342; Column = 24; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9998; Entrytime = 697338.8929; Column =  7; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 9999; Entrytime = 697405.2695; Column =  4; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# tote = 10000; Entrytime = 697494.6619; Column = 28; Mean throughput = 0.014337; Mean flowtime = 0.0000
#
# simulation has ended

# %% [markdown]
# c. Confirm that your simulations produce the correct throughput and flow time. Also determine the minimal and maximal column returned by your simulation.

# %% [markdown]
# Run your simulation at least 10 times. What is the range of outcomes for the mean throughput? Determine (roughly, by trial and error) the number of orders required to get good estimates for the throughput (first three non-zero digits are correct).

# %% [markdown]
# ## 6.2 Exercise 2: Demand Buffer (5 points)
# Next, we include the Demand buffer which is modelled as a standard FIFO buffer with infinite capacity.
#
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, and the exit process.

# %% [markdown]
# b. Complete the simulation code in the template below.
#
# Note: The previously defined variables and functions remain unchanged, only the Demand Buffer is added, and the main code is changed.

# %%
# =================================
# # Demand Buffer definition
# =================================
def Demand_Buffer(env, receiving_channel, sending_channel):
    xs = [] # list of totes
    while True:
            ### BEGIN SOLUTION
            receiving = receiving_channel.receive() 
            sending = sending_channel.send(xs[0]) if len(xs)>0 else None
            yield env.select(sending,receiving)
            if selected(sending):
                xs = xs[1:]
            if selected(receiving):
                x = receiving.received_entity
                xs = xs + [x]
            ### END SOLUTION

# =================================
# # Main
# =================================
env = Environment()
a = Channel(env)
b = Channel(env)
G = env.process(Generator(env, a))
D = env.process(Demand_Buffer(env, a,b))
E = env.process(Exit(env, b))
env.run(until=E)
print ("simulation has ended")
# Out:
# tote = 1; Entrytime =     0.0000; Column =  3; Mean throughput =      inf; Mean flowtime = 0.0000
#
# tote = 2; Entrytime =    39.8242; Column = 53; Mean throughput = 0.050221; Mean flowtime = 0.0000
#
# tote = 3; Entrytime =    54.5709; Column = 15; Mean throughput = 0.054974; Mean flowtime = 0.0000
#
# tote = 4; Entrytime =   100.6343; Column = 26; Mean throughput = 0.039748; Mean flowtime = 0.0000
#
# tote = 5; Entrytime =   116.1352; Column = 33; Mean throughput = 0.043053; Mean flowtime = 0.0000
#
# tote = 6; Entrytime =   158.1627; Column = 46; Mean throughput = 0.037936; Mean flowtime = 0.0000
#
# tote = 7; Entrytime =   159.1645; Column = 16; Mean throughput = 0.043980; Mean flowtime = 0.0000
#
# tote = 8; Entrytime =   185.8103; Column = 30; Mean throughput = 0.043055; Mean flowtime = 0.0000
#
# tote = 9; Entrytime =   212.1326; Column =  7; Mean throughput = 0.042426; Mean flowtime = 0.0000
#
# tote = 10; Entrytime =   536.3377; Column = 34; Mean throughput = 0.018645; Mean flowtime = 0.0000
#
# tote = 11; Entrytime =   635.3833; Column = 15; Mean throughput = 0.017312; Mean flowtime = 0.0000
#
# tote = 12; Entrytime =   660.6581; Column = 12; Mean throughput = 0.018164; Mean flowtime = 0.0000
#
# tote = 13; Entrytime =   721.3529; Column =  3; Mean throughput = 0.018022; Mean flowtime = 0.0000
#
# tote = 14; Entrytime =   830.8650; Column = 46; Mean throughput = 0.016850; Mean flowtime = 0.0000
#
# tote = 15; Entrytime =   838.7761; Column = 21; Mean throughput = 0.017883; Mean flowtime = 0.0000
#
# tote = 16; Entrytime =   906.7209; Column = 40; Mean throughput = 0.017646; Mean flowtime = 0.0000
#
# tote = 17; Entrytime =   953.3470; Column = 27; Mean throughput = 0.017832; Mean flowtime = 0.0000
#
# tote = 18; Entrytime =  1015.8791; Column = 44; Mean throughput = 0.017719; Mean flowtime = 0.0000
#
# tote = 19; Entrytime =  1018.0463; Column = 26; Mean throughput = 0.018663; Mean flowtime = 0.0000
#
# tote = 20; Entrytime =  1183.3621; Column =  9; Mean throughput = 0.016901; Mean flowtime = 0.0000
#
# tote = 21; Entrytime =  1223.3427; Column = 16; Mean throughput = 0.017166; Mean flowtime = 0.0000
#
# tote = 22; Entrytime =  1361.8634; Column = 35; Mean throughput = 0.016154; Mean flowtime = 0.0000
#
# tote = 23; Entrytime =  1501.1296; Column = 29; Mean throughput = 0.015322; Mean flowtime = 0.0000
#
# tote = 24; Entrytime =  1506.4331; Column = 48; Mean throughput = 0.015932; Mean flowtime = 0.0000
#
# tote = 25; Entrytime =  1508.1499; Column = 23; Mean throughput = 0.016577; Mean flowtime = 0.0000
#
# tote = 26; Entrytime =  1604.1681; Column = 49; Mean throughput = 0.016208; Mean flowtime = 0.0000
#
# tote = 27; Entrytime =  1618.6645; Column = 39; Mean throughput = 0.016680; Mean flowtime = 0.0000
#
# tote = 28; Entrytime =  1770.8397; Column = 26; Mean throughput = 0.015812; Mean flowtime = 0.0000
#
# tote = 29; Entrytime =  1789.8251; Column =  7; Mean throughput = 0.016203; Mean flowtime = 0.0000
#
# tote = 30; Entrytime =  1801.9559; Column = 20; Mean throughput = 0.016649; Mean flowtime = 0.0000
#
# tote = 31; Entrytime =  1840.6510; Column = 18; Mean throughput = 0.016842; Mean flowtime = 0.0000
#
# tote = 32; Entrytime =  1870.5045; Column = 50; Mean throughput = 0.017108; Mean flowtime = 0.0000
#
# tote = 33; Entrytime =  1898.5865; Column = 19; Mean throughput = 0.017381; Mean flowtime = 0.0000
#
# tote = 34; Entrytime =  1926.4851; Column = 43; Mean throughput = 0.017649; Mean flowtime = 0.0000
#
# tote = 35; Entrytime =  1960.0713; Column = 54; Mean throughput = 0.017856; Mean flowtime = 0.0000
#
# tote = 36; Entrytime =  1978.6141; Column = 28; Mean throughput = 0.018195; Mean flowtime = 0.0000
#
# tote = 37; Entrytime =  2039.6319; Column =  6; Mean throughput = 0.018141; Mean flowtime = 0.0000
#
# tote = 38; Entrytime =  2056.5872; Column = 42; Mean throughput = 0.018477; Mean flowtime = 0.0000
#
# tote = 39; Entrytime =  2091.2430; Column = 44; Mean throughput = 0.018649; Mean flowtime = 0.0000
#
# tote = 40; Entrytime =  2131.6449; Column = 42; Mean throughput = 0.018765; Mean flowtime = 0.0000
#
# tote = 41; Entrytime =  2190.2412; Column =  8; Mean throughput = 0.018719; Mean flowtime = 0.0000
#
# tote = 42; Entrytime =  2192.5044; Column = 38; Mean throughput = 0.019156; Mean flowtime = 0.0000
#
# tote = 43; Entrytime =  2208.8676; Column = 50; Mean throughput = 0.019467; Mean flowtime = 0.0000
#
# tote = 44; Entrytime =  2228.6375; Column = 41; Mean throughput = 0.019743; Mean flowtime = 0.0000
#
# tote = 45; Entrytime =  2337.9954; Column = 29; Mean throughput = 0.019247; Mean flowtime = 0.0000
#
# tote = 46; Entrytime =  2342.7031; Column = 16; Mean throughput = 0.019635; Mean flowtime = 0.0000
#
# tote = 47; Entrytime =  2346.8047; Column =  4; Mean throughput = 0.020027; Mean flowtime = 0.0000
#
# tote = 48; Entrytime =  2425.8553; Column = 20; Mean throughput = 0.019787; Mean flowtime = 0.0000
#
# tote = 49; Entrytime =  2451.7116; Column = 23; Mean throughput = 0.019986; Mean flowtime = 0.0000
#
# tote = 50; Entrytime =  2486.0019; Column = 29; Mean throughput = 0.020113; Mean flowtime = 0.0000
#
# tote = 51; Entrytime =  2571.3751; Column = 34; Mean throughput = 0.019834; Mean flowtime = 0.0000
#
# tote = 52; Entrytime =  2609.3080; Column = 19; Mean throughput = 0.019929; Mean flowtime = 0.0000
#
# tote = 53; Entrytime =  2701.8297; Column =  7; Mean throughput = 0.019616; Mean flowtime = 0.0000
#
# tote = 54; Entrytime =  2723.0817; Column =  1; Mean throughput = 0.019830; Mean flowtime = 0.0000
#
# tote = 55; Entrytime =  2769.2098; Column = 19; Mean throughput = 0.019861; Mean flowtime = 0.0000
#
# tote = 56; Entrytime =  2836.1289; Column = 52; Mean throughput = 0.019745; Mean flowtime = 0.0000
#
# tote = 57; Entrytime =  2850.8666; Column = 38; Mean throughput = 0.019994; Mean flowtime = 0.0000
#
# tote = 58; Entrytime =  2867.7383; Column = 21; Mean throughput = 0.020225; Mean flowtime = 0.0000
#
# tote = 59; Entrytime =  2909.1353; Column = 41; Mean throughput = 0.020281; Mean flowtime = 0.0000
#
# tote = 60; Entrytime =  2957.2551; Column = 22; Mean throughput = 0.020289; Mean flowtime = 0.0000
#
# tote = 61; Entrytime =  3093.6841; Column =  1; Mean throughput = 0.019718; Mean flowtime = 0.0000
#
# tote = 62; Entrytime =  3463.4030; Column = 25; Mean throughput = 0.017901; Mean flowtime = 0.0000
#
# tote = 63; Entrytime =  3564.6068; Column = 16; Mean throughput = 0.017674; Mean flowtime = 0.0000
#
# tote = 64; Entrytime =  3634.9422; Column = 24; Mean throughput = 0.017607; Mean flowtime = 0.0000
#
# tote = 65; Entrytime =  3680.5654; Column = 28; Mean throughput = 0.017660; Mean flowtime = 0.0000
#
# tote = 66; Entrytime =  3681.1195; Column = 37; Mean throughput = 0.017929; Mean flowtime = 0.0000
#
# tote = 67; Entrytime =  3703.0852; Column =  1; Mean throughput = 0.018093; Mean flowtime = 0.0000
#
# tote = 68; Entrytime =  3758.3639; Column = 30; Mean throughput = 0.018093; Mean flowtime = 0.0000
#
# tote = 69; Entrytime =  3833.2670; Column =  2; Mean throughput = 0.018000; Mean flowtime = 0.0000
#
# tote = 70; Entrytime =  3913.1633; Column = 11; Mean throughput = 0.017888; Mean flowtime = 0.0000
#
# tote = 71; Entrytime =  3952.5656; Column = 47; Mean throughput = 0.017963; Mean flowtime = 0.0000
#
# tote = 72; Entrytime =  4056.6504; Column = 13; Mean throughput = 0.017749; Mean flowtime = 0.0000
#
# tote = 73; Entrytime =  4121.5949; Column = 51; Mean throughput = 0.017712; Mean flowtime = 0.0000
#
# tote = 74; Entrytime =  4146.7252; Column =  9; Mean throughput = 0.017845; Mean flowtime = 0.0000
#
# tote = 75; Entrytime =  4226.8236; Column =  4; Mean throughput = 0.017744; Mean flowtime = 0.0000
#
# tote = 76; Entrytime =  4238.4932; Column = 42; Mean throughput = 0.017931; Mean flowtime = 0.0000
#
# tote = 77; Entrytime =  4280.6223; Column = 22; Mean throughput = 0.017988; Mean flowtime = 0.0000
#
# tote = 78; Entrytime =  4308.2036; Column = 43; Mean throughput = 0.018105; Mean flowtime = 0.0000
#
# tote = 79; Entrytime =  4319.8185; Column =  1; Mean throughput = 0.018288; Mean flowtime = 0.0000
#
# tote = 80; Entrytime =  4350.1445; Column = 39; Mean throughput = 0.018390; Mean flowtime = 0.0000
#
# tote = 81; Entrytime =  4521.0544; Column =  2; Mean throughput = 0.017916; Mean flowtime = 0.0000
#
# tote = 82; Entrytime =  4589.3559; Column = 23; Mean throughput = 0.017867; Mean flowtime = 0.0000
#
# tote = 83; Entrytime =  4770.1855; Column = 44; Mean throughput = 0.017400; Mean flowtime = 0.0000
#
# tote = 84; Entrytime =  4784.4010; Column = 31; Mean throughput = 0.017557; Mean flowtime = 0.0000
#
# tote = 85; Entrytime =  4832.4199; Column = 23; Mean throughput = 0.017590; Mean flowtime = 0.0000
#
# tote = 86; Entrytime =  4865.9405; Column = 27; Mean throughput = 0.017674; Mean flowtime = 0.0000
#
# tote = 87; Entrytime =  4873.3527; Column = 48; Mean throughput = 0.017852; Mean flowtime = 0.0000
#
# tote = 88; Entrytime =  4924.6443; Column = 45; Mean throughput = 0.017869; Mean flowtime = 0.0000
#
# tote = 89; Entrytime =  5038.3923; Column = 33; Mean throughput = 0.017664; Mean flowtime = 0.0000
#
# tote = 90; Entrytime =  5131.7867; Column = 15; Mean throughput = 0.017538; Mean flowtime = 0.0000
#
# tote = 91; Entrytime =  5145.8889; Column =  5; Mean throughput = 0.017684; Mean flowtime = 0.0000
#
# tote = 92; Entrytime =  5165.3255; Column = 49; Mean throughput = 0.017811; Mean flowtime = 0.0000
#
# tote = 93; Entrytime =  5262.4105; Column = 39; Mean throughput = 0.017673; Mean flowtime = 0.0000
#
# tote = 94; Entrytime =  5369.3164; Column = 34; Mean throughput = 0.017507; Mean flowtime = 0.0000
#
# tote = 95; Entrytime =  5465.2754; Column = 29; Mean throughput = 0.017382; Mean flowtime = 0.0000
#
# tote = 96; Entrytime =  5488.6757; Column = 12; Mean throughput = 0.017491; Mean flowtime = 0.0000
#
# tote = 97; Entrytime =  5489.1649; Column = 12; Mean throughput = 0.017671; Mean flowtime = 0.0000
#
# tote = 98; Entrytime =  5520.2825; Column = 54; Mean throughput = 0.017753; Mean flowtime = 0.0000
#
# tote = 99; Entrytime =  5531.0022; Column =  5; Mean throughput = 0.017899; Mean flowtime = 0.0000
#
# tote = 100; Entrytime =  5710.3945; Column =  3; Mean throughput = 0.017512; Mean flowtime = 0.0000
#
# tote = 101; Entrytime =  5767.1579; Column = 17; Mean throughput = 0.017513; Mean flowtime = 0.0000
#
# tote = 102; Entrytime =  5774.7833; Column =  8; Mean throughput = 0.017663; Mean flowtime = 0.0000
#
# tote = 103; Entrytime =  5800.6879; Column = 28; Mean throughput = 0.017757; Mean flowtime = 0.0000
#
# tote = 104; Entrytime =  5898.9556; Column = 13; Mean throughput = 0.017630; Mean flowtime = 0.0000
#
# tote = 105; Entrytime =  5936.8907; Column = 34; Mean throughput = 0.017686; Mean flowtime = 0.0000
#
# tote = 106; Entrytime =  6035.4813; Column = 30; Mean throughput = 0.017563; Mean flowtime = 0.0000
#
# tote = 107; Entrytime =  6043.9420; Column = 40; Mean throughput = 0.017704; Mean flowtime = 0.0000
#
# tote = 108; Entrytime =  6100.1028; Column = 20; Mean throughput = 0.017705; Mean flowtime = 0.0000
#
# tote = 109; Entrytime =  6367.9918; Column = 14; Mean throughput = 0.017117; Mean flowtime = 0.0000
#
# tote = 110; Entrytime =  6421.2208; Column = 20; Mean throughput = 0.017131; Mean flowtime = 0.0000
#
# tote = 111; Entrytime =  6433.9769; Column =  4; Mean throughput = 0.017252; Mean flowtime = 0.0000
#
# tote = 112; Entrytime =  6532.5200; Column = 47; Mean throughput = 0.017145; Mean flowtime = 0.0000
#
# tote = 113; Entrytime =  6664.6361; Column = 33; Mean throughput = 0.016955; Mean flowtime = 0.0000
#
# tote = 114; Entrytime =  6674.3410; Column = 52; Mean throughput = 0.017080; Mean flowtime = 0.0000
#
# tote = 115; Entrytime =  6700.3891; Column = 20; Mean throughput = 0.017163; Mean flowtime = 0.0000
#
# tote = 116; Entrytime =  6756.6781; Column =  7; Mean throughput = 0.017168; Mean flowtime = 0.0000
#
# tote = 117; Entrytime =  6765.6915; Column = 45; Mean throughput = 0.017293; Mean flowtime = 0.0000
#
# tote = 118; Entrytime =  6777.1897; Column = 34; Mean throughput = 0.017411; Mean flowtime = 0.0000
#
# tote = 119; Entrytime =  6831.1954; Column = 41; Mean throughput = 0.017420; Mean flowtime = 0.0000
#
# tote = 120; Entrytime =  6845.0363; Column = 15; Mean throughput = 0.017531; Mean flowtime = 0.0000
#
# tote = 121; Entrytime =  6946.2029; Column = 26; Mean throughput = 0.017420; Mean flowtime = 0.0000
#
# tote = 122; Entrytime =  6954.1765; Column = 44; Mean throughput = 0.017543; Mean flowtime = 0.0000
#
# tote = 123; Entrytime =  6998.2549; Column = 54; Mean throughput = 0.017576; Mean flowtime = 0.0000
#
# tote = 124; Entrytime =  7016.4007; Column = 49; Mean throughput = 0.017673; Mean flowtime = 0.0000
#
# tote = 125; Entrytime =  7182.9269; Column = 16; Mean throughput = 0.017402; Mean flowtime = 0.0000
#
# tote = 126; Entrytime =  7191.6658; Column = 48; Mean throughput = 0.017520; Mean flowtime = 0.0000
#
# tote = 127; Entrytime =  7216.4575; Column = 50; Mean throughput = 0.017599; Mean flowtime = 0.0000
#
# tote = 128; Entrytime =  7219.1673; Column = 28; Mean throughput = 0.017731; Mean flowtime = 0.0000
#
# tote = 129; Entrytime =  7352.4264; Column = 11; Mean throughput = 0.017545; Mean flowtime = 0.0000
#
# tote = 130; Entrytime =  7439.2161; Column = 31; Mean throughput = 0.017475; Mean flowtime = 0.0000
#
# tote = 131; Entrytime =  7489.5346; Column =  9; Mean throughput = 0.017491; Mean flowtime = 0.0000
#
# tote = 132; Entrytime =  7557.5197; Column = 53; Mean throughput = 0.017466; Mean flowtime = 0.0000
#
# tote = 133; Entrytime =  7595.6249; Column = 14; Mean throughput = 0.017510; Mean flowtime = 0.0000
#
# tote = 134; Entrytime =  7705.5592; Column = 28; Mean throughput = 0.017390; Mean flowtime = 0.0000
#
# tote = 135; Entrytime =  7761.7426; Column = 22; Mean throughput = 0.017393; Mean flowtime = 0.0000
#
# tote = 136; Entrytime =  7775.5421; Column = 47; Mean throughput = 0.017491; Mean flowtime = 0.0000
#
# tote = 137; Entrytime =  7799.8132; Column = 18; Mean throughput = 0.017565; Mean flowtime = 0.0000
#
# tote = 138; Entrytime =  7856.2903; Column =  2; Mean throughput = 0.017566; Mean flowtime = 0.0000
#
# tote = 139; Entrytime =  7914.1133; Column = 18; Mean throughput = 0.017564; Mean flowtime = 0.0000
#
# tote = 140; Entrytime =  7980.9755; Column = 23; Mean throughput = 0.017542; Mean flowtime = 0.0000
#
# tote = 141; Entrytime =  8027.3611; Column = 29; Mean throughput = 0.017565; Mean flowtime = 0.0000
#
# tote = 142; Entrytime =  8153.6828; Column = 41; Mean throughput = 0.017415; Mean flowtime = 0.0000
#
# tote = 143; Entrytime =  8184.2260; Column = 36; Mean throughput = 0.017473; Mean flowtime = 0.0000
#
# tote = 144; Entrytime =  8208.3295; Column =  7; Mean throughput = 0.017543; Mean flowtime = 0.0000
#
# tote = 145; Entrytime =  8242.6844; Column = 53; Mean throughput = 0.017591; Mean flowtime = 0.0000
#
# tote = 146; Entrytime =  8292.3701; Column =  8; Mean throughput = 0.017607; Mean flowtime = 0.0000
#
# tote = 147; Entrytime =  8336.9795; Column = 16; Mean throughput = 0.017632; Mean flowtime = 0.0000
#
# tote = 148; Entrytime =  8415.7969; Column = 26; Mean throughput = 0.017586; Mean flowtime = 0.0000
#
# tote = 149; Entrytime =  8650.1509; Column = 48; Mean throughput = 0.017225; Mean flowtime = 0.0000
#
# tote = 150; Entrytime =  8883.1396; Column = 10; Mean throughput = 0.016886; Mean flowtime = 0.0000
#
# tote = 151; Entrytime =  8911.4170; Column = 16; Mean throughput = 0.016945; Mean flowtime = 0.0000
#
# tote = 152; Entrytime =  8951.0442; Column = 27; Mean throughput = 0.016981; Mean flowtime = 0.0000
#
# tote = 153; Entrytime =  9080.8743; Column =  4; Mean throughput = 0.016849; Mean flowtime = 0.0000
#
# tote = 154; Entrytime =  9109.2283; Column = 45; Mean throughput = 0.016906; Mean flowtime = 0.0000
#
# tote = 155; Entrytime =  9141.1882; Column = 18; Mean throughput = 0.016956; Mean flowtime = 0.0000
#
# tote = 156; Entrytime =  9212.3823; Column = 19; Mean throughput = 0.016934; Mean flowtime = 0.0000
#
# tote = 157; Entrytime =  9334.3436; Column = 52; Mean throughput = 0.016820; Mean flowtime = 0.0000
#
# tote = 158; Entrytime =  9397.5024; Column =  1; Mean throughput = 0.016813; Mean flowtime = 0.0000
#
# tote = 159; Entrytime =  9437.8892; Column = 37; Mean throughput = 0.016847; Mean flowtime = 0.0000
#
# tote = 160; Entrytime =  9502.4420; Column = 38; Mean throughput = 0.016838; Mean flowtime = 0.0000
#
# tote = 161; Entrytime =  9502.4628; Column = 29; Mean throughput = 0.016943; Mean flowtime = 0.0000
#
# tote = 162; Entrytime =  9601.3426; Column = 13; Mean throughput = 0.016873; Mean flowtime = 0.0000
#
# tote = 163; Entrytime =  9650.8679; Column = 12; Mean throughput = 0.016890; Mean flowtime = 0.0000
#
# tote = 164; Entrytime =  9811.4780; Column = 44; Mean throughput = 0.016715; Mean flowtime = 0.0000
#
# tote = 165; Entrytime =  9817.4188; Column = 54; Mean throughput = 0.016807; Mean flowtime = 0.0000
#
# tote = 166; Entrytime = 10075.5650; Column =  9; Mean throughput = 0.016476; Mean flowtime = 0.0000
#
# tote = 167; Entrytime = 10192.4906; Column = 24; Mean throughput = 0.016385; Mean flowtime = 0.0000
#
# tote = 168; Entrytime = 10251.0553; Column = 27; Mean throughput = 0.016389; Mean flowtime = 0.0000
#
# tote = 169; Entrytime = 10261.8817; Column =  4; Mean throughput = 0.016469; Mean flowtime = 0.0000
#
# tote = 170; Entrytime = 10264.0384; Column = 54; Mean throughput = 0.016563; Mean flowtime = 0.0000
#
# tote = 171; Entrytime = 10477.9250; Column = 44; Mean throughput = 0.016320; Mean flowtime = 0.0000
#
# tote = 172; Entrytime = 10531.5859; Column =  2; Mean throughput = 0.016332; Mean flowtime = 0.0000
#
# tote = 173; Entrytime = 10690.7026; Column = 14; Mean throughput = 0.016182; Mean flowtime = 0.0000
#
# tote = 174; Entrytime = 10704.1912; Column = 11; Mean throughput = 0.016255; Mean flowtime = 0.0000
#
# tote = 175; Entrytime = 10710.1167; Column = 11; Mean throughput = 0.016340; Mean flowtime = 0.0000
#
# tote = 176; Entrytime = 10719.4595; Column = 37; Mean throughput = 0.016419; Mean flowtime = 0.0000
#
# tote = 177; Entrytime = 10754.2787; Column =  9; Mean throughput = 0.016459; Mean flowtime = 0.0000
#
# tote = 178; Entrytime = 10893.9807; Column = 48; Mean throughput = 0.016339; Mean flowtime = 0.0000
#
# tote = 179; Entrytime = 10894.3306; Column = 45; Mean throughput = 0.016431; Mean flowtime = 0.0000
#
# tote = 180; Entrytime = 10895.3908; Column = 17; Mean throughput = 0.016521; Mean flowtime = 0.0000
#
# tote = 181; Entrytime = 10913.1247; Column =  6; Mean throughput = 0.016586; Mean flowtime = 0.0000
#
# tote = 182; Entrytime = 11066.6929; Column = 46; Mean throughput = 0.016446; Mean flowtime = 0.0000
#
# tote = 183; Entrytime = 11086.7103; Column = 26; Mean throughput = 0.016506; Mean flowtime = 0.0000
#
# tote = 184; Entrytime = 11150.5962; Column = 19; Mean throughput = 0.016501; Mean flowtime = 0.0000
#
# tote = 185; Entrytime = 11163.4090; Column = 25; Mean throughput = 0.016572; Mean flowtime = 0.0000
#
# tote = 186; Entrytime = 11210.5598; Column = 41; Mean throughput = 0.016591; Mean flowtime = 0.0000
#
# tote = 187; Entrytime = 11270.3686; Column = 35; Mean throughput = 0.016592; Mean flowtime = 0.0000
#
# tote = 188; Entrytime = 11551.7321; Column = 43; Mean throughput = 0.016275; Mean flowtime = 0.0000
#
# tote = 189; Entrytime = 11665.0385; Column = 27; Mean throughput = 0.016202; Mean flowtime = 0.0000
#
# tote = 190; Entrytime = 11671.6266; Column =  8; Mean throughput = 0.016279; Mean flowtime = 0.0000
#
# tote = 191; Entrytime = 11856.2831; Column = 41; Mean throughput = 0.016110; Mean flowtime = 0.0000
#
# tote = 192; Entrytime = 11917.6805; Column =  6; Mean throughput = 0.016111; Mean flowtime = 0.0000
#
# tote = 193; Entrytime = 11918.4846; Column = 22; Mean throughput = 0.016193; Mean flowtime = 0.0000
#
# tote = 194; Entrytime = 11919.2249; Column = 40; Mean throughput = 0.016276; Mean flowtime = 0.0000
#
# tote = 195; Entrytime = 11978.6262; Column = 44; Mean throughput = 0.016279; Mean flowtime = 0.0000
#
# tote = 196; Entrytime = 12083.3582; Column = 21; Mean throughput = 0.016221; Mean flowtime = 0.0000
#
# tote = 197; Entrytime = 12105.3192; Column =  4; Mean throughput = 0.016274; Mean flowtime = 0.0000
#
# tote = 198; Entrytime = 12140.2478; Column = 51; Mean throughput = 0.016309; Mean flowtime = 0.0000
#
# tote = 199; Entrytime = 12221.2843; Column = 42; Mean throughput = 0.016283; Mean flowtime = 0.0000
#
# tote = 200; Entrytime = 12246.5657; Column =  4; Mean throughput = 0.016331; Mean flowtime = 0.0000
#
# tote = 201; Entrytime = 12284.5561; Column = 12; Mean throughput = 0.016362; Mean flowtime = 0.0000
#
# tote = 202; Entrytime = 12463.2131; Column = 24; Mean throughput = 0.016208; Mean flowtime = 0.0000
#
# tote = 203; Entrytime = 12487.9369; Column = 51; Mean throughput = 0.016256; Mean flowtime = 0.0000
#
# tote = 204; Entrytime = 12510.4353; Column = 31; Mean throughput = 0.016306; Mean flowtime = 0.0000
#
# tote = 205; Entrytime = 12594.4237; Column = 33; Mean throughput = 0.016277; Mean flowtime = 0.0000
#
# tote = 206; Entrytime = 12621.2549; Column = 48; Mean throughput = 0.016322; Mean flowtime = 0.0000
#
# tote = 207; Entrytime = 12694.5410; Column = 30; Mean throughput = 0.016306; Mean flowtime = 0.0000
#
# tote = 208; Entrytime = 12709.9231; Column = 14; Mean throughput = 0.016365; Mean flowtime = 0.0000
#
# tote = 209; Entrytime = 12829.5558; Column = 40; Mean throughput = 0.016291; Mean flowtime = 0.0000
#
# tote = 210; Entrytime = 12836.5927; Column = 47; Mean throughput = 0.016359; Mean flowtime = 0.0000
#
# tote = 211; Entrytime = 12872.8395; Column = 11; Mean throughput = 0.016391; Mean flowtime = 0.0000
#
# tote = 212; Entrytime = 12892.6603; Column = 27; Mean throughput = 0.016443; Mean flowtime = 0.0000
#
# tote = 213; Entrytime = 12979.3654; Column = 41; Mean throughput = 0.016411; Mean flowtime = 0.0000
#
# tote = 214; Entrytime = 13043.1752; Column = 15; Mean throughput = 0.016407; Mean flowtime = 0.0000
#
# tote = 215; Entrytime = 13056.6211; Column = 27; Mean throughput = 0.016467; Mean flowtime = 0.0000
#
# tote = 216; Entrytime = 13098.6022; Column = 16; Mean throughput = 0.016490; Mean flowtime = 0.0000
#
# tote = 217; Entrytime = 13106.2249; Column = 50; Mean throughput = 0.016557; Mean flowtime = 0.0000
#
# tote = 218; Entrytime = 13155.0507; Column = 26; Mean throughput = 0.016572; Mean flowtime = 0.0000
#
# tote = 219; Entrytime = 13177.0348; Column = 19; Mean throughput = 0.016620; Mean flowtime = 0.0000
#
# tote = 220; Entrytime = 13256.4795; Column = 20; Mean throughput = 0.016596; Mean flowtime = 0.0000
#
# tote = 221; Entrytime = 13402.3404; Column = 20; Mean throughput = 0.016490; Mean flowtime = 0.0000
#
# tote = 222; Entrytime = 13526.9569; Column = 50; Mean throughput = 0.016412; Mean flowtime = 0.0000
#
# tote = 223; Entrytime = 13733.1105; Column = 38; Mean throughput = 0.016238; Mean flowtime = 0.0000
#
# tote = 224; Entrytime = 13751.6239; Column = 33; Mean throughput = 0.016289; Mean flowtime = 0.0000
#
# tote = 225; Entrytime = 13789.3801; Column = 11; Mean throughput = 0.016317; Mean flowtime = 0.0000
#
# tote = 226; Entrytime = 13789.6957; Column = 31; Mean throughput = 0.016389; Mean flowtime = 0.0000
#
# tote = 227; Entrytime = 13843.2288; Column =  2; Mean throughput = 0.016398; Mean flowtime = 0.0000
#
# tote = 228; Entrytime = 13868.9080; Column = 30; Mean throughput = 0.016440; Mean flowtime = 0.0000
#
# tote = 229; Entrytime = 13894.0656; Column = 49; Mean throughput = 0.016482; Mean flowtime = 0.0000
#
# tote = 230; Entrytime = 13960.1013; Column = 35; Mean throughput = 0.016476; Mean flowtime = 0.0000
#
# tote = 231; Entrytime = 13991.0922; Column = 43; Mean throughput = 0.016511; Mean flowtime = 0.0000
#
# tote = 232; Entrytime = 14061.3228; Column = 36; Mean throughput = 0.016499; Mean flowtime = 0.0000
#
# tote = 233; Entrytime = 14118.1117; Column = 43; Mean throughput = 0.016504; Mean flowtime = 0.0000
#
# tote = 234; Entrytime = 14166.7897; Column = 53; Mean throughput = 0.016518; Mean flowtime = 0.0000
#
# tote = 235; Entrytime = 14326.7304; Column = 37; Mean throughput = 0.016403; Mean flowtime = 0.0000
#
# tote = 236; Entrytime = 14400.4150; Column =  3; Mean throughput = 0.016388; Mean flowtime = 0.0000
#
# tote = 237; Entrytime = 14418.0856; Column = 18; Mean throughput = 0.016438; Mean flowtime = 0.0000
#
# tote = 238; Entrytime = 14454.5155; Column = 30; Mean throughput = 0.016465; Mean flowtime = 0.0000
#
# tote = 239; Entrytime = 14653.2407; Column = 28; Mean throughput = 0.016310; Mean flowtime = 0.0000
#
# tote = 240; Entrytime = 14727.5922; Column = 51; Mean throughput = 0.016296; Mean flowtime = 0.0000
#
# tote = 241; Entrytime = 14912.1242; Column =  2; Mean throughput = 0.016161; Mean flowtime = 0.0000
#
# tote = 242; Entrytime = 14929.4885; Column = 11; Mean throughput = 0.016210; Mean flowtime = 0.0000
#
# tote = 243; Entrytime = 15038.6036; Column = 46; Mean throughput = 0.016158; Mean flowtime = 0.0000
#
# tote = 244; Entrytime = 15099.1573; Column = 14; Mean throughput = 0.016160; Mean flowtime = 0.0000
#
# tote = 245; Entrytime = 15109.0372; Column = 49; Mean throughput = 0.016215; Mean flowtime = 0.0000
#
# tote = 246; Entrytime = 15136.4368; Column = 31; Mean throughput = 0.016252; Mean flowtime = 0.0000
#
# tote = 247; Entrytime = 15184.4351; Column = 25; Mean throughput = 0.016267; Mean flowtime = 0.0000
#
# tote = 248; Entrytime = 15275.0268; Column = 26; Mean throughput = 0.016236; Mean flowtime = 0.0000
#
# tote = 249; Entrytime = 15295.3588; Column = 35; Mean throughput = 0.016279; Mean flowtime = 0.0000
#
# tote = 250; Entrytime = 15296.5417; Column =  1; Mean throughput = 0.016344; Mean flowtime = 0.0000
#
# tote = 251; Entrytime = 15302.9300; Column = 16; Mean throughput = 0.016402; Mean flowtime = 0.0000
#
# tote = 252; Entrytime = 15322.7747; Column = 33; Mean throughput = 0.016446; Mean flowtime = 0.0000
#
# tote = 253; Entrytime = 15355.2724; Column = 17; Mean throughput = 0.016476; Mean flowtime = 0.0000
#
# tote = 254; Entrytime = 15375.6184; Column = 38; Mean throughput = 0.016520; Mean flowtime = 0.0000
#
# tote = 255; Entrytime = 15419.9829; Column = 29; Mean throughput = 0.016537; Mean flowtime = 0.0000
#
# tote = 256; Entrytime = 15461.0935; Column = 22; Mean throughput = 0.016558; Mean flowtime = 0.0000
#
# tote = 257; Entrytime = 15625.2191; Column = 25; Mean throughput = 0.016448; Mean flowtime = 0.0000
#
# tote = 258; Entrytime = 15627.6138; Column = 23; Mean throughput = 0.016509; Mean flowtime = 0.0000
#
# tote = 259; Entrytime = 15795.6551; Column = 43; Mean throughput = 0.016397; Mean flowtime = 0.0000
#
# tote = 260; Entrytime = 15822.5813; Column = 37; Mean throughput = 0.016432; Mean flowtime = 0.0000
#
# tote = 261; Entrytime = 15925.1816; Column = 18; Mean throughput = 0.016389; Mean flowtime = 0.0000
#
# tote = 262; Entrytime = 15931.5825; Column = 31; Mean throughput = 0.016445; Mean flowtime = 0.0000
#
# tote = 263; Entrytime = 16038.9713; Column = 36; Mean throughput = 0.016398; Mean flowtime = 0.0000
#
# tote = 264; Entrytime = 16188.8623; Column = 11; Mean throughput = 0.016308; Mean flowtime = 0.0000
#
# tote = 265; Entrytime = 16211.9351; Column = 43; Mean throughput = 0.016346; Mean flowtime = 0.0000
#
# tote = 266; Entrytime = 16356.5238; Column =  2; Mean throughput = 0.016263; Mean flowtime = 0.0000
#
# tote = 267; Entrytime = 16574.4439; Column = 52; Mean throughput = 0.016109; Mean flowtime = 0.0000
#
# tote = 268; Entrytime = 16615.0095; Column = 15; Mean throughput = 0.016130; Mean flowtime = 0.0000
#
# tote = 269; Entrytime = 16840.5825; Column = 46; Mean throughput = 0.015973; Mean flowtime = 0.0000
#
# tote = 270; Entrytime = 16877.7666; Column = 38; Mean throughput = 0.015997; Mean flowtime = 0.0000
#
# tote = 271; Entrytime = 16920.4546; Column = 40; Mean throughput = 0.016016; Mean flowtime = 0.0000
#
# tote = 272; Entrytime = 16942.4213; Column = 20; Mean throughput = 0.016054; Mean flowtime = 0.0000
#
# tote = 273; Entrytime = 16981.0557; Column = 26; Mean throughput = 0.016077; Mean flowtime = 0.0000
#
# tote = 274; Entrytime = 17011.3336; Column = 39; Mean throughput = 0.016107; Mean flowtime = 0.0000
#
# tote = 275; Entrytime = 17026.6148; Column =  3; Mean throughput = 0.016151; Mean flowtime = 0.0000
#
# tote = 276; Entrytime = 17079.9040; Column = 22; Mean throughput = 0.016159; Mean flowtime = 0.0000
#
# tote = 277; Entrytime = 17105.0929; Column =  5; Mean throughput = 0.016194; Mean flowtime = 0.0000
#
# tote = 278; Entrytime = 17171.5186; Column = 43; Mean throughput = 0.016190; Mean flowtime = 0.0000
#
# tote = 279; Entrytime = 17190.5364; Column = 21; Mean throughput = 0.016230; Mean flowtime = 0.0000
#
# tote = 280; Entrytime = 17248.2634; Column = 42; Mean throughput = 0.016234; Mean flowtime = 0.0000
#
# tote = 281; Entrytime = 17361.7480; Column = 33; Mean throughput = 0.016185; Mean flowtime = 0.0000
#
# tote = 282; Entrytime = 17410.9748; Column = 10; Mean throughput = 0.016197; Mean flowtime = 0.0000
#
# tote = 283; Entrytime = 17501.1500; Column = 39; Mean throughput = 0.016170; Mean flowtime = 0.0000
#
# tote = 284; Entrytime = 17655.9982; Column =  7; Mean throughput = 0.016085; Mean flowtime = 0.0000
#
# tote = 285; Entrytime = 17682.1264; Column =  6; Mean throughput = 0.016118; Mean flowtime = 0.0000
#
# tote = 286; Entrytime = 17800.5145; Column = 31; Mean throughput = 0.016067; Mean flowtime = 0.0000
#
# tote = 287; Entrytime = 17828.9007; Column = 15; Mean throughput = 0.016097; Mean flowtime = 0.0000
#
# tote = 288; Entrytime = 18002.5128; Column = 44; Mean throughput = 0.015998; Mean flowtime = 0.0000
#
# tote = 289; Entrytime = 18004.6644; Column = 54; Mean throughput = 0.016051; Mean flowtime = 0.0000
#
# tote = 290; Entrytime = 18099.2705; Column = 36; Mean throughput = 0.016023; Mean flowtime = 0.0000
#
# tote = 291; Entrytime = 18137.1742; Column = 14; Mean throughput = 0.016044; Mean flowtime = 0.0000
#
# tote = 292; Entrytime = 18251.1505; Column =  7; Mean throughput = 0.015999; Mean flowtime = 0.0000
#
# tote = 293; Entrytime = 18263.8686; Column = 15; Mean throughput = 0.016043; Mean flowtime = 0.0000
#
# tote = 294; Entrytime = 18283.7138; Column = 37; Mean throughput = 0.016080; Mean flowtime = 0.0000
#
# tote = 295; Entrytime = 18353.2901; Column = 17; Mean throughput = 0.016073; Mean flowtime = 0.0000
#
# tote = 296; Entrytime = 18425.4270; Column = 53; Mean throughput = 0.016065; Mean flowtime = 0.0000
#
# tote = 297; Entrytime = 18570.3944; Column = 43; Mean throughput = 0.015993; Mean flowtime = 0.0000
#
# tote = 298; Entrytime = 18635.0212; Column = 11; Mean throughput = 0.015991; Mean flowtime = 0.0000
#
# tote = 299; Entrytime = 18691.0113; Column = 17; Mean throughput = 0.015997; Mean flowtime = 0.0000
#
# tote = 300; Entrytime = 18932.0874; Column = 29; Mean throughput = 0.015846; Mean flowtime = 0.0000
#
# tote = 301; Entrytime = 18968.7152; Column = 38; Mean throughput = 0.015868; Mean flowtime = 0.0000
#
# tote = 302; Entrytime = 19033.6306; Column = 35; Mean throughput = 0.015867; Mean flowtime = 0.0000
#
# tote = 303; Entrytime = 19090.8523; Column = 35; Mean throughput = 0.015871; Mean flowtime = 0.0000
#
# tote = 304; Entrytime = 19136.7991; Column = 28; Mean throughput = 0.015886; Mean flowtime = 0.0000
#
# tote = 305; Entrytime = 19137.9779; Column = 33; Mean throughput = 0.015937; Mean flowtime = 0.0000
#
# tote = 306; Entrytime = 19239.7093; Column = 31; Mean throughput = 0.015905; Mean flowtime = 0.0000
#
# tote = 307; Entrytime = 19272.7639; Column = 49; Mean throughput = 0.015929; Mean flowtime = 0.0000
#
# tote = 308; Entrytime = 19279.4891; Column = 27; Mean throughput = 0.015976; Mean flowtime = 0.0000
#
# tote = 309; Entrytime = 19417.9757; Column =  6; Mean throughput = 0.015913; Mean flowtime = 0.0000
#
# tote = 310; Entrytime = 19525.9612; Column = 44; Mean throughput = 0.015876; Mean flowtime = 0.0000
#
# tote = 311; Entrytime = 19571.1031; Column = 48; Mean throughput = 0.015891; Mean flowtime = 0.0000
#
# tote = 312; Entrytime = 19713.4343; Column = 13; Mean throughput = 0.015827; Mean flowtime = 0.0000
#
# tote = 313; Entrytime = 19716.7019; Column = 44; Mean throughput = 0.015875; Mean flowtime = 0.0000
#
# tote = 314; Entrytime = 19779.0617; Column = 17; Mean throughput = 0.015875; Mean flowtime = 0.0000
#
# tote = 315; Entrytime = 19779.9141; Column = 49; Mean throughput = 0.015925; Mean flowtime = 0.0000
#
# tote = 316; Entrytime = 19786.1257; Column = 44; Mean throughput = 0.015971; Mean flowtime = 0.0000
#
# tote = 317; Entrytime = 19837.7733; Column =  2; Mean throughput = 0.015980; Mean flowtime = 0.0000
#
# tote = 318; Entrytime = 19865.2186; Column = 23; Mean throughput = 0.016008; Mean flowtime = 0.0000
#
# tote = 319; Entrytime = 19915.7486; Column = 52; Mean throughput = 0.016017; Mean flowtime = 0.0000
#
# tote = 320; Entrytime = 19938.6364; Column =  1; Mean throughput = 0.016049; Mean flowtime = 0.0000
#
# tote = 321; Entrytime = 19961.5825; Column = 10; Mean throughput = 0.016081; Mean flowtime = 0.0000
#
# tote = 322; Entrytime = 20007.2596; Column = 16; Mean throughput = 0.016094; Mean flowtime = 0.0000
#
# tote = 323; Entrytime = 20155.5791; Column = 33; Mean throughput = 0.016025; Mean flowtime = 0.0000
#
# tote = 324; Entrytime = 20185.3509; Column =  7; Mean throughput = 0.016051; Mean flowtime = 0.0000
#
# tote = 325; Entrytime = 20348.0870; Column =  7; Mean throughput = 0.015972; Mean flowtime = 0.0000
#
# tote = 326; Entrytime = 20393.8341; Column = 48; Mean throughput = 0.015985; Mean flowtime = 0.0000
#
# tote = 327; Entrytime = 20486.5700; Column = 11; Mean throughput = 0.015962; Mean flowtime = 0.0000
#
# tote = 328; Entrytime = 20536.3281; Column =  6; Mean throughput = 0.015972; Mean flowtime = 0.0000
#
# tote = 329; Entrytime = 20564.5890; Column = 10; Mean throughput = 0.015998; Mean flowtime = 0.0000
#
# tote = 330; Entrytime = 20566.5378; Column = 49; Mean throughput = 0.016045; Mean flowtime = 0.0000
#
# tote = 331; Entrytime = 20592.5725; Column = 42; Mean throughput = 0.016074; Mean flowtime = 0.0000
#
# tote = 332; Entrytime = 20622.6364; Column = 36; Mean throughput = 0.016099; Mean flowtime = 0.0000
#
# tote = 333; Entrytime = 20634.0637; Column =  2; Mean throughput = 0.016138; Mean flowtime = 0.0000
#
# tote = 334; Entrytime = 20641.0861; Column = 49; Mean throughput = 0.016181; Mean flowtime = 0.0000
#
# tote = 335; Entrytime = 20650.8123; Column = 34; Mean throughput = 0.016222; Mean flowtime = 0.0000
#
# tote = 336; Entrytime = 20681.3549; Column = 16; Mean throughput = 0.016247; Mean flowtime = 0.0000
#
# tote = 337; Entrytime = 20726.7504; Column = 40; Mean throughput = 0.016259; Mean flowtime = 0.0000
#
# tote = 338; Entrytime = 20933.4572; Column = 46; Mean throughput = 0.016146; Mean flowtime = 0.0000
#
# tote = 339; Entrytime = 20956.7638; Column = 27; Mean throughput = 0.016176; Mean flowtime = 0.0000
#
# tote = 340; Entrytime = 21097.4942; Column = 16; Mean throughput = 0.016116; Mean flowtime = 0.0000
#
# tote = 341; Entrytime = 21119.1081; Column = 30; Mean throughput = 0.016147; Mean flowtime = 0.0000
#
# tote = 342; Entrytime = 21149.4934; Column =  9; Mean throughput = 0.016171; Mean flowtime = 0.0000
#
# tote = 343; Entrytime = 21213.4252; Column = 26; Mean throughput = 0.016169; Mean flowtime = 0.0000
#
# tote = 344; Entrytime = 21236.0105; Column = 36; Mean throughput = 0.016199; Mean flowtime = 0.0000
#
# tote = 345; Entrytime = 21242.5963; Column = 14; Mean throughput = 0.016241; Mean flowtime = 0.0000
#
# tote = 346; Entrytime = 21377.0240; Column =  3; Mean throughput = 0.016186; Mean flowtime = 0.0000
#
# tote = 347; Entrytime = 21549.9939; Column = 27; Mean throughput = 0.016102; Mean flowtime = 0.0000
#
# tote = 348; Entrytime = 21580.2890; Column = 16; Mean throughput = 0.016126; Mean flowtime = 0.0000
#
# tote = 349; Entrytime = 21654.3975; Column = 28; Mean throughput = 0.016117; Mean flowtime = 0.0000
#
# tote = 350; Entrytime = 21683.7350; Column = 39; Mean throughput = 0.016141; Mean flowtime = 0.0000
#
# tote = 351; Entrytime = 22037.8096; Column = 10; Mean throughput = 0.015927; Mean flowtime = 0.0000
#
# tote = 352; Entrytime = 22105.6534; Column = 43; Mean throughput = 0.015924; Mean flowtime = 0.0000
#
# tote = 353; Entrytime = 22305.4077; Column = 28; Mean throughput = 0.015826; Mean flowtime = 0.0000
#
# tote = 354; Entrytime = 22552.4920; Column = 14; Mean throughput = 0.015697; Mean flowtime = 0.0000
#
# tote = 355; Entrytime = 22629.7162; Column = 27; Mean throughput = 0.015687; Mean flowtime = 0.0000
#
# tote = 356; Entrytime = 22679.7573; Column = 36; Mean throughput = 0.015697; Mean flowtime = 0.0000
#
# tote = 357; Entrytime = 22744.3518; Column = 21; Mean throughput = 0.015696; Mean flowtime = 0.0000
#
# tote = 358; Entrytime = 22784.2333; Column = 30; Mean throughput = 0.015713; Mean flowtime = 0.0000
#
# tote = 359; Entrytime = 22831.5112; Column = 20; Mean throughput = 0.015724; Mean flowtime = 0.0000
#
# tote = 360; Entrytime = 22894.2227; Column = 11; Mean throughput = 0.015724; Mean flowtime = 0.0000
#
# tote = 361; Entrytime = 22980.0051; Column = 29; Mean throughput = 0.015709; Mean flowtime = 0.0000
#
# tote = 362; Entrytime = 23105.7338; Column = 35; Mean throughput = 0.015667; Mean flowtime = 0.0000
#
# tote = 363; Entrytime = 23153.3344; Column = 29; Mean throughput = 0.015678; Mean flowtime = 0.0000
#
# tote = 364; Entrytime = 23167.8913; Column = 53; Mean throughput = 0.015711; Mean flowtime = 0.0000
#
# tote = 365; Entrytime = 23245.6774; Column = 45; Mean throughput = 0.015702; Mean flowtime = 0.0000
#
# tote = 366; Entrytime = 23448.1212; Column =  2; Mean throughput = 0.015609; Mean flowtime = 0.0000
#
# tote = 367; Entrytime = 23539.9209; Column =  9; Mean throughput = 0.015591; Mean flowtime = 0.0000
#
# tote = 368; Entrytime = 23716.5063; Column = 24; Mean throughput = 0.015517; Mean flowtime = 0.0000
#
# tote = 369; Entrytime = 23819.3740; Column = 39; Mean throughput = 0.015492; Mean flowtime = 0.0000
#
# tote = 370; Entrytime = 23826.6539; Column = 22; Mean throughput = 0.015529; Mean flowtime = 0.0000
#
# tote = 371; Entrytime = 23962.0593; Column = 13; Mean throughput = 0.015483; Mean flowtime = 0.0000
#
# tote = 372; Entrytime = 23987.6461; Column = 15; Mean throughput = 0.015508; Mean flowtime = 0.0000
#
# tote = 373; Entrytime = 24077.5737; Column = 23; Mean throughput = 0.015492; Mean flowtime = 0.0000
#
# tote = 374; Entrytime = 24094.2675; Column = 50; Mean throughput = 0.015522; Mean flowtime = 0.0000
#
# tote = 375; Entrytime = 24103.0972; Column = 27; Mean throughput = 0.015558; Mean flowtime = 0.0000
#
# tote = 376; Entrytime = 24356.4521; Column = 54; Mean throughput = 0.015437; Mean flowtime = 0.0000
#
# tote = 377; Entrytime = 24366.1515; Column = 39; Mean throughput = 0.015472; Mean flowtime = 0.0000
#
# tote = 378; Entrytime = 24396.8759; Column = 23; Mean throughput = 0.015494; Mean flowtime = 0.0000
#
# tote = 379; Entrytime = 24421.2898; Column = 16; Mean throughput = 0.015519; Mean flowtime = 0.0000
#
# tote = 380; Entrytime = 24435.0952; Column = 45; Mean throughput = 0.015551; Mean flowtime = 0.0000
#
# tote = 381; Entrytime = 24530.7046; Column = 18; Mean throughput = 0.015532; Mean flowtime = 0.0000
#
# tote = 382; Entrytime = 24544.1670; Column = 20; Mean throughput = 0.015564; Mean flowtime = 0.0000
#
# tote = 383; Entrytime = 24576.5554; Column =  2; Mean throughput = 0.015584; Mean flowtime = 0.0000
#
# tote = 384; Entrytime = 24752.1735; Column = 27; Mean throughput = 0.015514; Mean flowtime = 0.0000
#
# tote = 385; Entrytime = 24776.6868; Column = 36; Mean throughput = 0.015539; Mean flowtime = 0.0000
#
# tote = 386; Entrytime = 24799.9811; Column = 54; Mean throughput = 0.015565; Mean flowtime = 0.0000
#
# tote = 387; Entrytime = 24898.6701; Column = 49; Mean throughput = 0.015543; Mean flowtime = 0.0000
#
# tote = 388; Entrytime = 25071.7256; Column = 29; Mean throughput = 0.015476; Mean flowtime = 0.0000
#
# tote = 389; Entrytime = 25283.0856; Column = 42; Mean throughput = 0.015386; Mean flowtime = 0.0000
#
# tote = 390; Entrytime = 25293.8083; Column = 27; Mean throughput = 0.015419; Mean flowtime = 0.0000
#
# tote = 391; Entrytime = 25314.8146; Column = 48; Mean throughput = 0.015446; Mean flowtime = 0.0000
#
# tote = 392; Entrytime = 25443.6430; Column = 45; Mean throughput = 0.015407; Mean flowtime = 0.0000
#
# tote = 393; Entrytime = 25473.6483; Column =  9; Mean throughput = 0.015428; Mean flowtime = 0.0000
#
# tote = 394; Entrytime = 25491.6174; Column =  4; Mean throughput = 0.015456; Mean flowtime = 0.0000
#
# tote = 395; Entrytime = 25552.5925; Column = 17; Mean throughput = 0.015458; Mean flowtime = 0.0000
#
# tote = 396; Entrytime = 25692.9888; Column = 41; Mean throughput = 0.015413; Mean flowtime = 0.0000
#
# tote = 397; Entrytime = 25766.8516; Column = 14; Mean throughput = 0.015407; Mean flowtime = 0.0000
#
# tote = 398; Entrytime = 25962.5252; Column =  2; Mean throughput = 0.015330; Mean flowtime = 0.0000
#
# tote = 399; Entrytime = 26001.4236; Column = 45; Mean throughput = 0.015345; Mean flowtime = 0.0000
#
# tote = 400; Entrytime = 26013.7412; Column = 48; Mean throughput = 0.015376; Mean flowtime = 0.0000
#
# tote = 401; Entrytime = 26102.7663; Column = 27; Mean throughput = 0.015362; Mean flowtime = 0.0000
#
# tote = 402; Entrytime = 26389.9863; Column = 47; Mean throughput = 0.015233; Mean flowtime = 0.0000
#
# tote = 403; Entrytime = 26431.8139; Column = 20; Mean throughput = 0.015247; Mean flowtime = 0.0000
#
# tote = 404; Entrytime = 26528.9600; Column = 44; Mean throughput = 0.015229; Mean flowtime = 0.0000
#
# tote = 405; Entrytime = 26581.7744; Column = 52; Mean throughput = 0.015236; Mean flowtime = 0.0000
#
# tote = 406; Entrytime = 26623.5387; Column = 10; Mean throughput = 0.015250; Mean flowtime = 0.0000
#
# tote = 407; Entrytime = 26658.2714; Column = 47; Mean throughput = 0.015267; Mean flowtime = 0.0000
#
# tote = 408; Entrytime = 26732.5433; Column = 41; Mean throughput = 0.015262; Mean flowtime = 0.0000
#
# tote = 409; Entrytime = 26809.6566; Column = 32; Mean throughput = 0.015256; Mean flowtime = 0.0000
#
# tote = 410; Entrytime = 26837.5685; Column = 22; Mean throughput = 0.015277; Mean flowtime = 0.0000
#
# tote = 411; Entrytime = 26850.7475; Column = 26; Mean throughput = 0.015307; Mean flowtime = 0.0000
#
# tote = 412; Entrytime = 26979.3751; Column =  9; Mean throughput = 0.015271; Mean flowtime = 0.0000
#
# tote = 413; Entrytime = 27000.6809; Column = 12; Mean throughput = 0.015296; Mean flowtime = 0.0000
#
# tote = 414; Entrytime = 27053.5326; Column = 37; Mean throughput = 0.015303; Mean flowtime = 0.0000
#
# tote = 415; Entrytime = 27061.7711; Column = 39; Mean throughput = 0.015335; Mean flowtime = 0.0000
#
# tote = 416; Entrytime = 27174.5524; Column = 15; Mean throughput = 0.015308; Mean flowtime = 0.0000
#
# tote = 417; Entrytime = 27197.6217; Column = 53; Mean throughput = 0.015332; Mean flowtime = 0.0000
#
# tote = 418; Entrytime = 27247.9552; Column = 22; Mean throughput = 0.015341; Mean flowtime = 0.0000
#
# tote = 419; Entrytime = 27292.0083; Column = 33; Mean throughput = 0.015352; Mean flowtime = 0.0000
#
# tote = 420; Entrytime = 27341.6854; Column = 49; Mean throughput = 0.015361; Mean flowtime = 0.0000
#
# tote = 421; Entrytime = 27486.1127; Column = 39; Mean throughput = 0.015317; Mean flowtime = 0.0000
#
# tote = 422; Entrytime = 27503.5568; Column = 26; Mean throughput = 0.015343; Mean flowtime = 0.0000
#
# tote = 423; Entrytime = 27551.4068; Column = 48; Mean throughput = 0.015353; Mean flowtime = 0.0000
#
# tote = 424; Entrytime = 27607.3852; Column = 24; Mean throughput = 0.015358; Mean flowtime = 0.0000
#
# tote = 425; Entrytime = 27621.1658; Column = 54; Mean throughput = 0.015387; Mean flowtime = 0.0000
#
# tote = 426; Entrytime = 27659.5602; Column =  7; Mean throughput = 0.015402; Mean flowtime = 0.0000
#
# tote = 427; Entrytime = 27729.0323; Column = 45; Mean throughput = 0.015399; Mean flowtime = 0.0000
#
# tote = 428; Entrytime = 27771.5621; Column = 32; Mean throughput = 0.015411; Mean flowtime = 0.0000
#
# tote = 429; Entrytime = 27832.0524; Column = 53; Mean throughput = 0.015414; Mean flowtime = 0.0000
#
# tote = 430; Entrytime = 27889.7234; Column =  2; Mean throughput = 0.015418; Mean flowtime = 0.0000
#
# tote = 431; Entrytime = 27975.3348; Column =  3; Mean throughput = 0.015406; Mean flowtime = 0.0000
#
# tote = 432; Entrytime = 27991.8578; Column = 46; Mean throughput = 0.015433; Mean flowtime = 0.0000
#
# tote = 433; Entrytime = 28100.4105; Column = 15; Mean throughput = 0.015409; Mean flowtime = 0.0000
#
# tote = 434; Entrytime = 28150.5195; Column = 14; Mean throughput = 0.015417; Mean flowtime = 0.0000
#
# tote = 435; Entrytime = 28214.7352; Column = 51; Mean throughput = 0.015417; Mean flowtime = 0.0000
#
# tote = 436; Entrytime = 28268.0654; Column = 52; Mean throughput = 0.015424; Mean flowtime = 0.0000
#
# tote = 437; Entrytime = 28388.5449; Column = 16; Mean throughput = 0.015394; Mean flowtime = 0.0000
#
# tote = 438; Entrytime = 28496.1919; Column = 24; Mean throughput = 0.015370; Mean flowtime = 0.0000
#
# tote = 439; Entrytime = 28615.7144; Column = 32; Mean throughput = 0.015341; Mean flowtime = 0.0000
#
# tote = 440; Entrytime = 28637.9705; Column = 31; Mean throughput = 0.015364; Mean flowtime = 0.0000
#
# tote = 441; Entrytime = 28660.4899; Column = 35; Mean throughput = 0.015387; Mean flowtime = 0.0000
#
# tote = 442; Entrytime = 28749.9586; Column = 15; Mean throughput = 0.015374; Mean flowtime = 0.0000
#
# tote = 443; Entrytime = 28792.9832; Column =  6; Mean throughput = 0.015386; Mean flowtime = 0.0000
#
# tote = 444; Entrytime = 28809.0026; Column = 28; Mean throughput = 0.015412; Mean flowtime = 0.0000
#
# tote = 445; Entrytime = 28809.6565; Column = 27; Mean throughput = 0.015446; Mean flowtime = 0.0000
#
# tote = 446; Entrytime = 28852.2854; Column = 32; Mean throughput = 0.015458; Mean flowtime = 0.0000
#
# tote = 447; Entrytime = 28865.7797; Column = 10; Mean throughput = 0.015485; Mean flowtime = 0.0000
#
# tote = 448; Entrytime = 28965.1798; Column = 41; Mean throughput = 0.015467; Mean flowtime = 0.0000
#
# tote = 449; Entrytime = 28981.9287; Column = 24; Mean throughput = 0.015492; Mean flowtime = 0.0000
#
# tote = 450; Entrytime = 28996.4052; Column =  7; Mean throughput = 0.015519; Mean flowtime = 0.0000
#
# tote = 451; Entrytime = 29113.8389; Column = 38; Mean throughput = 0.015491; Mean flowtime = 0.0000
#
# tote = 452; Entrytime = 29136.1052; Column = 32; Mean throughput = 0.015513; Mean flowtime = 0.0000
#
# tote = 453; Entrytime = 29179.0812; Column = 49; Mean throughput = 0.015525; Mean flowtime = 0.0000
#
# tote = 454; Entrytime = 29206.0914; Column = 15; Mean throughput = 0.015545; Mean flowtime = 0.0000
#
# tote = 455; Entrytime = 29251.4872; Column = 32; Mean throughput = 0.015555; Mean flowtime = 0.0000
#
# tote = 456; Entrytime = 29415.1902; Column = 14; Mean throughput = 0.015502; Mean flowtime = 0.0000
#
# tote = 457; Entrytime = 29431.3693; Column = 26; Mean throughput = 0.015528; Mean flowtime = 0.0000
#
# tote = 458; Entrytime = 29582.1275; Column =  9; Mean throughput = 0.015482; Mean flowtime = 0.0000
#
# tote = 459; Entrytime = 29650.6219; Column = 27; Mean throughput = 0.015480; Mean flowtime = 0.0000
#
# tote = 460; Entrytime = 29662.3900; Column = 29; Mean throughput = 0.015508; Mean flowtime = 0.0000
#
# tote = 461; Entrytime = 29699.5778; Column = 46; Mean throughput = 0.015522; Mean flowtime = 0.0000
#
# tote = 462; Entrytime = 30079.7855; Column = 16; Mean throughput = 0.015359; Mean flowtime = 0.0000
#
# tote = 463; Entrytime = 30108.6974; Column = 50; Mean throughput = 0.015378; Mean flowtime = 0.0000
#
# tote = 464; Entrytime = 30195.3265; Column = 48; Mean throughput = 0.015367; Mean flowtime = 0.0000
#
# tote = 465; Entrytime = 30211.8312; Column = 52; Mean throughput = 0.015391; Mean flowtime = 0.0000
#
# tote = 466; Entrytime = 30243.5805; Column = 23; Mean throughput = 0.015408; Mean flowtime = 0.0000
#
# tote = 467; Entrytime = 30312.0941; Column = 28; Mean throughput = 0.015406; Mean flowtime = 0.0000
#
# tote = 468; Entrytime = 30436.1425; Column = 12; Mean throughput = 0.015376; Mean flowtime = 0.0000
#
# tote = 469; Entrytime = 30498.3774; Column = 21; Mean throughput = 0.015378; Mean flowtime = 0.0000
#
# tote = 470; Entrytime = 30509.1166; Column = 19; Mean throughput = 0.015405; Mean flowtime = 0.0000
#
# tote = 471; Entrytime = 30537.2647; Column = 46; Mean throughput = 0.015424; Mean flowtime = 0.0000
#
# tote = 472; Entrytime = 30539.3740; Column = 23; Mean throughput = 0.015455; Mean flowtime = 0.0000
#
# tote = 473; Entrytime = 30598.6949; Column = 48; Mean throughput = 0.015458; Mean flowtime = 0.0000
#
# tote = 474; Entrytime = 30660.6818; Column = 32; Mean throughput = 0.015460; Mean flowtime = 0.0000
#
# tote = 475; Entrytime = 30717.6709; Column =  6; Mean throughput = 0.015463; Mean flowtime = 0.0000
#
# tote = 476; Entrytime = 30789.8498; Column =  3; Mean throughput = 0.015460; Mean flowtime = 0.0000
#
# ...
#
# tote = 9846; Entrytime = 698749.7795; Column = 34; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9847; Entrytime = 698793.1534; Column = 44; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9848; Entrytime = 698842.9181; Column = 43; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9849; Entrytime = 698990.4033; Column = 19; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9850; Entrytime = 698994.6523; Column = 47; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9851; Entrytime = 699095.8019; Column = 30; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9852; Entrytime = 699098.7837; Column = 29; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9853; Entrytime = 699160.9261; Column = 19; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9854; Entrytime = 699222.5547; Column = 21; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9855; Entrytime = 699362.0803; Column = 20; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9856; Entrytime = 699476.1595; Column = 31; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9857; Entrytime = 699569.3738; Column = 39; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9858; Entrytime = 699575.2712; Column = 49; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9859; Entrytime = 699583.1499; Column = 42; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9860; Entrytime = 699666.4183; Column = 36; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9861; Entrytime = 699681.2246; Column = 42; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9862; Entrytime = 699691.1252; Column =  3; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9863; Entrytime = 699774.0948; Column = 40; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9864; Entrytime = 699899.3879; Column = 10; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9865; Entrytime = 699999.5097; Column = 48; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9866; Entrytime = 700096.9972; Column = 53; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9867; Entrytime = 700150.3639; Column = 38; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9868; Entrytime = 700173.3441; Column = 25; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9869; Entrytime = 700219.3012; Column = 47; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9870; Entrytime = 700321.0542; Column = 17; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9871; Entrytime = 700539.5042; Column = 24; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9872; Entrytime = 700758.3277; Column = 33; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9873; Entrytime = 700785.9824; Column = 47; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9874; Entrytime = 700796.4228; Column = 35; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9875; Entrytime = 700824.0018; Column = 15; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9876; Entrytime = 700940.5634; Column = 54; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9877; Entrytime = 701045.2249; Column = 13; Mean throughput = 0.014089; Mean flowtime = 0.0000
#
# tote = 9878; Entrytime = 701150.6310; Column =  4; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9879; Entrytime = 701295.2676; Column = 22; Mean throughput = 0.014087; Mean flowtime = 0.0000
#
# tote = 9880; Entrytime = 701317.6786; Column =  2; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9881; Entrytime = 701404.5371; Column = 28; Mean throughput = 0.014087; Mean flowtime = 0.0000
#
# tote = 9882; Entrytime = 701466.3966; Column = 27; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9883; Entrytime = 701489.6763; Column =  6; Mean throughput = 0.014089; Mean flowtime = 0.0000
#
# tote = 9884; Entrytime = 701491.9755; Column = 13; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9885; Entrytime = 701667.1821; Column = 39; Mean throughput = 0.014088; Mean flowtime = 0.0000
#
# tote = 9886; Entrytime = 701675.4472; Column = 15; Mean throughput = 0.014089; Mean flowtime = 0.0000
#
# tote = 9887; Entrytime = 701704.8119; Column = 21; Mean throughput = 0.014090; Mean flowtime = 0.0000
#
# tote = 9888; Entrytime = 701739.8867; Column = 25; Mean throughput = 0.014091; Mean flowtime = 0.0000
#
# tote = 9889; Entrytime = 701766.1021; Column = 23; Mean throughput = 0.014092; Mean flowtime = 0.0000
#
# tote = 9890; Entrytime = 701769.1546; Column = 18; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9891; Entrytime = 701817.2415; Column = 11; Mean throughput = 0.014093; Mean flowtime = 0.0000
#
# tote = 9892; Entrytime = 701835.2624; Column = 30; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9893; Entrytime = 701899.4314; Column =  7; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9894; Entrytime = 701932.7508; Column = 29; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9895; Entrytime = 701960.9455; Column = 16; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9896; Entrytime = 701999.6382; Column = 35; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9897; Entrytime = 702042.3517; Column =  7; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9898; Entrytime = 702073.8580; Column = 43; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9899; Entrytime = 702207.9979; Column = 41; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9900; Entrytime = 702238.2415; Column = 13; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9901; Entrytime = 702364.7374; Column = 33; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9902; Entrytime = 702405.4878; Column = 30; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9903; Entrytime = 702411.1261; Column = 45; Mean throughput = 0.014099; Mean flowtime = 0.0000
#
# tote = 9904; Entrytime = 702417.1159; Column = 44; Mean throughput = 0.014100; Mean flowtime = 0.0000
#
# tote = 9905; Entrytime = 702465.0749; Column =  1; Mean throughput = 0.014100; Mean flowtime = 0.0000
#
# tote = 9906; Entrytime = 702483.1860; Column = 24; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9907; Entrytime = 702537.3603; Column =  7; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9908; Entrytime = 702541.5380; Column = 44; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9909; Entrytime = 702606.5258; Column = 34; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9910; Entrytime = 702629.6161; Column = 25; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9911; Entrytime = 702673.9574; Column =  4; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9912; Entrytime = 702691.7621; Column = 51; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9913; Entrytime = 703001.6676; Column =  9; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9914; Entrytime = 703068.8770; Column = 35; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9915; Entrytime = 703080.6414; Column = 46; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9916; Entrytime = 703102.2051; Column = 34; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9917; Entrytime = 703138.1306; Column =  8; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9918; Entrytime = 703207.5721; Column = 18; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9919; Entrytime = 703301.3822; Column = 18; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9920; Entrytime = 703469.5646; Column = 29; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9921; Entrytime = 703580.4852; Column =  9; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9922; Entrytime = 703631.9684; Column = 31; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9923; Entrytime = 703745.9218; Column = 22; Mean throughput = 0.014100; Mean flowtime = 0.0000
#
# tote = 9924; Entrytime = 703751.7626; Column = 46; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9925; Entrytime = 703759.0220; Column = 21; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9926; Entrytime = 703829.4574; Column = 15; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9927; Entrytime = 703874.2245; Column =  5; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9928; Entrytime = 703962.9219; Column = 48; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9929; Entrytime = 703977.8343; Column = 39; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9930; Entrytime = 704051.4930; Column = 18; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9931; Entrytime = 704082.2756; Column = 26; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9932; Entrytime = 704098.1022; Column = 37; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9933; Entrytime = 704226.3234; Column = 42; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9934; Entrytime = 704238.2222; Column =  7; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9935; Entrytime = 704247.7304; Column =  5; Mean throughput = 0.014107; Mean flowtime = 0.0000
#
# tote = 9936; Entrytime = 704416.9871; Column = 11; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9937; Entrytime = 704461.8901; Column = 30; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9938; Entrytime = 704477.7811; Column = 45; Mean throughput = 0.014107; Mean flowtime = 0.0000
#
# tote = 9939; Entrytime = 704667.6314; Column =  9; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9940; Entrytime = 704690.1662; Column = 22; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9941; Entrytime = 704735.0418; Column = 54; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9942; Entrytime = 704832.6874; Column = 13; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9943; Entrytime = 704891.4423; Column = 44; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9944; Entrytime = 704927.9675; Column = 22; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9945; Entrytime = 705086.9732; Column = 27; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9946; Entrytime = 705128.4899; Column = 25; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9947; Entrytime = 705148.5674; Column = 29; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9948; Entrytime = 705373.7125; Column = 26; Mean throughput = 0.014103; Mean flowtime = 0.0000
#
# tote = 9949; Entrytime = 705419.7881; Column = 45; Mean throughput = 0.014104; Mean flowtime = 0.0000
#
# tote = 9950; Entrytime = 705432.0829; Column = 17; Mean throughput = 0.014105; Mean flowtime = 0.0000
#
# tote = 9951; Entrytime = 705455.9604; Column =  3; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9952; Entrytime = 705520.9159; Column = 25; Mean throughput = 0.014106; Mean flowtime = 0.0000
#
# tote = 9953; Entrytime = 705818.3861; Column = 40; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9954; Entrytime = 706003.7556; Column = 17; Mean throughput = 0.014099; Mean flowtime = 0.0000
#
# tote = 9955; Entrytime = 706030.7389; Column = 51; Mean throughput = 0.014100; Mean flowtime = 0.0000
#
# tote = 9956; Entrytime = 706055.4508; Column = 27; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9957; Entrytime = 706089.3006; Column = 46; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9958; Entrytime = 706151.1005; Column = 10; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9959; Entrytime = 706237.3319; Column = 29; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9960; Entrytime = 706308.7778; Column = 46; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9961; Entrytime = 706390.6630; Column = 42; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9962; Entrytime = 706488.6303; Column = 48; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9963; Entrytime = 706544.9081; Column = 38; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9964; Entrytime = 706565.1362; Column = 14; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9965; Entrytime = 706657.9952; Column = 24; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9966; Entrytime = 706760.9185; Column = 30; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9967; Entrytime = 706784.4192; Column = 25; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9968; Entrytime = 706912.4870; Column = 18; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9969; Entrytime = 707143.3055; Column = 44; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9970; Entrytime = 707220.4135; Column = 30; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9971; Entrytime = 707486.0331; Column = 24; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9972; Entrytime = 707486.4401; Column = 27; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9973; Entrytime = 707597.2954; Column = 25; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9974; Entrytime = 707636.4821; Column = 36; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9975; Entrytime = 707655.0408; Column = 51; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9976; Entrytime = 707695.2792; Column = 32; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9977; Entrytime = 707745.2263; Column = 38; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9978; Entrytime = 707768.2927; Column = 44; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9979; Entrytime = 707809.7739; Column = 15; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9980; Entrytime = 707949.7669; Column = 28; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9981; Entrytime = 708053.7792; Column = 49; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9982; Entrytime = 708071.4724; Column =  1; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9983; Entrytime = 708116.2355; Column = 30; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9984; Entrytime = 708164.5780; Column =  8; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9985; Entrytime = 708194.9813; Column = 46; Mean throughput = 0.014099; Mean flowtime = 0.0000
#
# tote = 9986; Entrytime = 708217.3670; Column = 46; Mean throughput = 0.014100; Mean flowtime = 0.0000
#
# tote = 9987; Entrytime = 708272.6681; Column = 31; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9988; Entrytime = 708325.3139; Column = 10; Mean throughput = 0.014101; Mean flowtime = 0.0000
#
# tote = 9989; Entrytime = 708351.9653; Column =  2; Mean throughput = 0.014102; Mean flowtime = 0.0000
#
# tote = 9990; Entrytime = 708563.4245; Column = 15; Mean throughput = 0.014099; Mean flowtime = 0.0000
#
# tote = 9991; Entrytime = 708671.3265; Column = 46; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9992; Entrytime = 708793.3718; Column = 20; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9993; Entrytime = 708862.2867; Column = 42; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 9994; Entrytime = 709105.9962; Column = 51; Mean throughput = 0.014094; Mean flowtime = 0.0000
#
# tote = 9995; Entrytime = 709116.1285; Column = 42; Mean throughput = 0.014095; Mean flowtime = 0.0000
#
# tote = 9996; Entrytime = 709118.2368; Column = 42; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9997; Entrytime = 709129.1104; Column = 15; Mean throughput = 0.014098; Mean flowtime = 0.0000
#
# tote = 9998; Entrytime = 709257.2028; Column = 24; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# tote = 9999; Entrytime = 709303.7199; Column = 22; Mean throughput = 0.014097; Mean flowtime = 0.0000
#
# tote = 10000; Entrytime = 709410.0071; Column = 22; Mean throughput = 0.014096; Mean flowtime = 0.0000
#
# simulation has ended

# %% [markdown]
# c. Confirm that your simulations produce the correct throughput and flow time.

# %% [markdown]
# ## 6.3 Exercise 3: Vehicle as machine (5 points)
# Next, we include the Vehicle which as a first attempt is modelled as a standard machine with a deterministic processing time of 40.0 seconds
#
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, vehicle and the exit process.

# %% [markdown]
# b. Complete the simulation code in the template below.
#
# Note: The previously defined variables and functions remain unchanged, only the Vehicle is added, and the main code is changed.

# %%
# =================================
# # Vehicle definition
# =================================
def Vehicle(env, receiving_channel, sending_channel):
    ### BEGIN SOLUTION
    tp = 40.0  # processing time
    while True:
        receive = receiving_channel.receive()
        x = yield env.select(receive)
        yield env.timeout(tp) 
        send = sending_channel.send(x)
        yield env.select(send)
    ### END SOLUTION
        
# =================================
# # Main
# =================================
env = Environment()
a = Channel(env)
b = Channel(env)
c = Channel(env)
G = env.process(Generator(env, a))
D = env.process(Demand_Buffer(env, a,b))
V = env.process(Vehicle(env, b,c))
E = env.process(Exit(env, c))
env.run(until=E)
print ("simulation has ended")

# %% [markdown]
# c. Confirm that your simulations produce the correct throughput and flow time.

# %% [markdown]
# d. Run your simulation at least 10 times. What is the range of outcomes for the mean throughput? Determine (roughly/ by trial and error) the number of orders required to get good estimates for the flow time (first three non-zero digits are correct).

# %% [markdown]
# ## 6.4 Exercise 4: Vehicle accurately modelled (15 points)
# Assume that a vehicle starts from the buffer. If it has to go to column $i \in \{0, depth - 1\}$, it needs to drive a distance $dv \cdot (i + 1)$, pick up the tote, drive back, and deliver the tote to the buffer. For driving the required distance, the vehicle first goes with a constant acceleration `av` *m/s$^2$* until it reaches its maximum velocity `vmaxv`, then it moves with this velocity and decelerates with a constant deceleration `av` to approach its destination point. If the tote is located too close to the end of the aisle, it is possible that the vehicle will not reach its maximum speed.
#
# a. From this information, (analytically) determine the time (in seconds) it takes a vehicle to drive a given distance of x meters. To that end, first determine from the acceleration profile the travelled distance as function of time. From that you can determine the time required to travel a given distance.

# %% [markdown]
# b. Next, if loading and unloading a tote both take `lv` seconds, determine (analytically) the time it takes a vehicle, starting from the buffer, to pick up a tote from column $i \in \{0, depth\}$ and deliver it to the buffer.

# %% [markdown]
# c. Determine (analytically) the mean and variance of this total travel time for a random (uniformly distributed) column.

# %% [markdown]
# d. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, vehicle and the exit process.

# %% [markdown]
# e. Complete the simulation code in the template below, incorporating the actual time a vehicle requires for picking up a tote and delivering it to the buffer.
#
# Note: the previously defined variables and functions remain unchanged, only the Vehicle needs to be redefined.
#
# <span style="color:red">(Ik ben het niet helemaal eens met hoe de vehicle gemodelleerd wordt.)</span>

# %%
# =================================
# # Global vehicle variables
# =================================
lv = 3.0                  # time to load/unload the vehicle
dv = 0.5                  # unit width clearance
vmaxv = 1.5              # maximum velocity of the vehicle
av = 1.0                  # acceleration/deceleration of the vehicle

# =================================
# # Vehicle definition
# =================================
def Vehicle(env, receiving_channel, sending_channel):
    ### BEGIN SOLUTION
    while True: 
        receive = receiving_channel.receive()
        x = yield env.select(receive)
        
        distance = dv*x.column
        if distance <= vmaxv**2/av:
            t_travel = math.sqrt(4*distance/av)
        else:
            t_travel = 2*vmaxv/av  +  (distance-vmaxv**2/av)/vmaxv
        
        # TODO: eigenlijk zou je hier pas het item kunnen ophalen, maar zo wordt het niet gemodelleerd.
        # De reden is natuurlijk dat je in dat geval geen idee hebt waar je naartoe moet rijden. Dit zou eigenlijk eerst verstuurd moeten worden.
        #  x = yield receiving_channel.receive()
        # TODO: Daarnaast, zou je pas kunnen unloaden als er een plekje vrij is in de buffer.
        # Dus pas als de buffer ready is om te ontvangen, heb je nog lv seconden nodig om het ook echt in de buffer te plaatsen.
        #  yield env.timeout(t_travel)
        #  yield sending_channel.readyto_send()
        #  yield env.timeout(lv)
        #  yield sending_channel.send(x)
        te_processing = 2*t_travel+2*lv
        yield env.timeout(te_processing)
        
        send = sending_channel.send(x)  
        yield env.select(send)    
    ### END SOLUTION

# =================================
# # Main
# =================================
env = Environment()
a = Channel(env)
b = Channel(env)
c = Channel(env)
G = env.process(Generator(env, a))
D = env.process(Demand_Buffer(env, a,b))
V = env.process(Vehicle(env, b,c))
E = env.process(Exit(env, c))
env.run(until=E)
print ("simulation has ended")

# %% [markdown]
# f. Confirm that your simulations produce the correct throughput and flow time.

# %% [markdown]
# g.  Run your simulation at least 10 times. What is the range of outcomes for the mean throughput? Determine (roughly, by trial and error) the number of orders required to get good estimates for the flow time (first three non-zero digits are correct).

# %% [markdown]
# ## 6.5 Exercise 5: Lift as two stage machine (5 points)
# In the previous exercises we focussed on modeling a tier. In exercises 5-8 we focus on modeling the Buffer and Lift, starting with the Lift. We model the Lift as a machine, which repeatedly does the following: request a destination tier, move to the desired tier, receive a tote (first delay for `ll`, then communicate), move to the ground floor, deliver the tote (first delay for `ll`, then communicate). In this exercise we assume that moving to the desired tier takes 23.0 seconds, receiving the tote takes 2.0 seconds, moving to the ground floor again takes 23.0 seconds, and delivering the tote also takes 2.0 seconds. Note that, in this case, this implies that the tote should leave the Generator and enter the Lift 25.0 seconds after the Lift has received the destination tier. All of these times are assumed to be deterministic.
#
# a. Assume that after 1.0 second the first tote arrives. Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job spends in the Generator, and spends in the Lift.

# %% [markdown]
# b. Complete the simulation code in the template below, incorporating the actual time a vehicle requires for picking up a tote and delivering it to the buffer.
#
# Note: we first reinitalize the entire simulation, as changes are made in the entire simulation model (generator, lift, exit, etc.)

# %%
# %reset -f
from numpy import random
import simpy
import math
import numpy
numpy.seterr(divide='ignore')
from Course_4DC10.simChi.core.channel_select import Channel, process, selected, Environment
from dataclasses import dataclass
# Out:
# SimChi version 20210730 imported succesfully.

# %%
# =================================
# # Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0
    tier: int = 0

# =================================
# # Global Lift variables
# =================================
ll = 2.0  # time to load/unload the lift


# =================================
# # Generator definition
# =================================
def Generator(env, sending_channel, call_lift_channel):
    delays=[1.0, 10.0, 100.0, 100.0]
    while len(delays)>0:
        delay = env.timeout(delays[0])
        yield delay
        delays = delays[1:]
        
        send = call_lift_channel.send(1)
        yield env.select(send)
        print("Generator: Informed Lift to go to tier 1 at time %3.1f" % env.now);
        # TODO? De tijd wordt bepaald op het moment dat je gaat wachten
        # Eigenlijk moet de tijd bepaald worden op het moment dat je echt verstuurd!
        # Als je x daarvoor definieert, dan krijg je een andere entry time 
        # dan als je x definieert op het moment van sturen.
        ## Dit geldt ook voor alle andere exercises
        x = Tote()
        x.entrytime = env.now
        x.tier = 1 
        send = sending_channel.send(x)
        yield env.select(send)
        print("Generator: Tote has completely left the Generator and entered the Lift at time %3.1f" % env.now)
    delay = env.timeout(100.0)
    yield delay


# =================================
# # Lift definition
# =================================
def Lift(env, receiving_channel, call_lift_channel, sending_channel):
    ### BEGIN SOLUTION
    while True:
        lift_called = call_lift_channel.receive()
        yield env.select(lift_called)
        
        t_travel = 23.0
        yield env.timeout(t_travel+ll)
        
        receive = receiving_channel.receive()       
        yield env.select(receive)
        x = receive.received_entity
        
        yield env.timeout(t_travel+ll)
        
        send = sending_channel.send(x)
        yield env.select(send)
    ### END SOLUTION

    
# =================================
# # Exit definition
# =================================
def Exit(env, receiving_channel):
    while True:
        receive = receiving_channel.receive()
        x = yield env.select(receive)
        print("Exit:      Tote has completely left the Lift and has been received by the Exit at time %3.1f" % env.now);


# =================================
# # Main
# =================================
env = Environment()
a = Channel(env)  # for sending lots
b = Channel(env)  # lift tier
c = Channel(env)  # for sending lots
G = env.process(Generator(env, a, b))
L = env.process(Lift(env, a, b, c))
E = env.process(Exit(env, c))
env.run()
print ("simulation has ended")
# Out:
# Generator: Informed Lift to go to tier 1 at time 1.0
# Generator: Tote has completely left the Generator and entered the Lift at time 26.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 51.0
# Generator: Informed Lift to go to tier 1 at time 51.0
# Generator: Tote has completely left the Generator and entered the Lift at time 76.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 101.0
# Generator: Informed Lift to go to tier 1 at time 176.0
# Generator: Tote has completely left the Generator and entered the Lift at time 201.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 226.0
# Generator: Informed Lift to go to tier 1 at time 301.0
# Generator: Tote has completely left the Generator and entered the Lift at time 326.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 351.0
# simulation has ended

# %% [markdown]
# c. Confirm that your simulations produce the correct results, i.e., in correspondence with your lot-time-diagram.

# %% [markdown]
# ## 6.6 Exercise 6: Buffer with only one tier (5 points)
# In case we have only one tier, we could use a standard model for a finite buffer. However, keeping in mind that we need to model in the next exercise Level finite buffers in parallel where totes are served at a first-come-first-serve basis, we model the finite buffer slightly differently. We have a counter `n` which counts the number of jobs in the buffer, and we keep a list `xs` of totes that have arrived to the buffer. As long as the buffer contains less than `bc` totes, the buffer can receive jobs. Furthermore, if the buffer contains totes, it is possible to receive a request from the Lift (asking for which tier to move to, which is always 0 in this case). Additionally, if the buffer contains totes it is possible to send the first tote of the list `xs` to the lift.
#
# a. Assume that after 1.0 second the first tote arrives. Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job spends in the Generator, in the Buffer, and spends in the Lift.

# %% [markdown]
#  b. Complete the simulation code in the template below, only the Generator and Buffer need to be redefined.

# %%
# =================================
# # Global Lift variables
# =================================
ll = 2.0  # time to load/unload the lift
bc = 1    # buffer capacity

# =================================
# # Generator definition
# =================================
def Generator(env, sending_channel):
    delays=[1.0, 10.0, 100.0, 100.0]
    while len(delays)>0:
        delay = env.timeout(delays[0])
        yield delay
        delays = delays[1:]
        
        x = Tote()
        x.entrytime = env.now
        x.tier = 0
        send = sending_channel.send(x)
        yield env.select(send)
        print("Generator: sending tote to Buffer at time %3.1f" % env.now)
    delay = env.timeout(100.0)
    yield delay

# =================================
## Buffer definition
# =================================
def Buffer(env, receiving_channel, sending_channel, call_lift_channel):
    xs = [] # list of jobs
    n = 0
    while True:
        receiving = receiving_channel.receive() if n < bc else None
        call_lift = call_lift_channel.send(xs[0].tier) if len(xs) > 0 else None
        sending   = sending_channel.send(xs[0]) if len(xs)>0 else None
        
        yield env.select(receiving, call_lift, sending)

        if selected(receiving):
            x = receiving.received_entity
            xs = xs + [x]
            n = n+1
        
        if selected(call_lift):
            pass
        
        if selected(sending):
            ### BEGIN SOLUTION
            xs = xs[1:]
            n = n - 1
            ### END SOLUTION
            
# =================================
## Main
# =================================
env = Environment()
a = Channel(env)  # for sending lots
b = Channel(env)  # for sending lots
c = Channel(env)  # for calling the lift
d = Channel(env)  # for sending lots

G = env.process(Generator(env, a))
B = env.process(Buffer(env, a, b, c))
L = env.process(Lift(env, b, c, d))
E = env.process(Exit(env, d))
env.run()
print ("simulation has ended")
# Out:
# Generator: sending tote to Buffer at time 1.0
# Generator: sending tote to Buffer at time 26.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 51.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 101.0
# Generator: sending tote to Buffer at time 126.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 176.0
# Generator: sending tote to Buffer at time 226.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 276.0
# simulation has ended

# %% [markdown]
# c. Confirm that your simulations produce the correct results, i.e., in correspondence with your lot-time-diagram

# %% [markdown]
# ## Exercise 7: Buffer with multiple tiers (5 points)
# We extend the buffer from the previous exercise to `Level` parallel finite buffers of size `bc` which are modelled as a list of `Level` counters. For this list we use the variable `n`. We keep a common list `xs` of totes that have arrived to all buffers. This list is used to determine which tote should be picked up first by the Lift. For each of the tiers it holds that if the buffer of that tier is not full yet, a tote can be received. Furthermore, if the buffer contains totes, it is possible to receive a request from the Lift asking for the tier to move to. Additionally, if the buffer contains totes it is possible to send the first tote of the list `xs` to the lift.

# %% [markdown]
# a. Consider two tiers, and assume that after `Tier` seconds the first tote arrives (for two tiers: after 0.0 for tier 0 and
# after 1.0 for tier 1). Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion
# of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job
# spends in which Generator, in the Buffer, and spends in the Lift.

# %% [markdown]
# b. Complete the simulation code in the template below.

# %%
from Course_4DC10.simChi.core.channel_select import Channel, process, selected, Environment
# =================================
# # Global variables
# =================================
ll = 2.0  # time to load/unload the lift
bc = 1    # buffer capacity
Level = 2 # the number of tiers

# =================================
# # Generator definition
# =================================
def Generator(env, sending_channel, level):
    delays=[1.0*level, 10.0, 100.0, 100.0]
    while len(delays)>0:
        delay = env.timeout(delays[0])
        yield delay
        delays = delays[1:]
        
        x = Tote()
        x.entrytime = env.now
        x.tier = level
        send = sending_channel.send(x)
        yield env.select(send)
        print("Generator %d: Sending tote to Buffer completed at time %3.1f" % (level, env.now) )
    delay = env.timeout(100.0)
    yield delay 
    
# =================================
# # Buffer definition
# =================================
def Buffer(env, receiving_channels, sending_channel, call_lift_channel):
    xs = []
    n = [0] * Level
    while True:
        receiving = [receiving_channels[Tier].receive() if n[Tier] < bc else None for Tier in range(Level) ]
        call_lift = call_lift_channel.send(xs[0].tier) if len(xs) > 0 else None
        sending = sending_channel.send(xs[0]) if len(xs) > 0 else None
        communications = receiving + [call_lift] + [sending]
        yield env.select(*communications)
        
        for Tier in range(Level):
            if selected(receiving[Tier]):
                x = receiving[Tier].received_entity
                xs = xs + [x]
                n[Tier] = n[Tier] + 1
        
        if selected(call_lift):
            pass
            
        if selected(sending):
            ### BEGIN SOLUTION
            Tier = xs[0].tier 
            xs = xs[1:]
            n[Tier] = n[Tier] - 1
            ### END SOLUTION
            
# =================================
# # Main
# =================================
env = Environment()
a = [Channel(env) for tier in range(Level)] # a channel for each tier, each sending lots
b = Channel(env)  # for sending lots
c = Channel(env)  # for calling the lift
d = Channel(env)  # for sending lots
Gs = [env.process(Generator(env, a[tier], tier)) for tier in range(Level)] 
B = env.process(Buffer(env, a, b, c))
L = env.process(Lift(env, b, c, d))
E = env.process(Exit(env, d))
env.run(until=1000000)
print ("simulation has ended")
# Out:
# Generator 0: Sending tote to Buffer completed at time 0.0
# Generator 1: Sending tote to Buffer completed at time 1.0
# Generator 0: Sending tote to Buffer completed at time 25.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 50.0
# Generator 1: Sending tote to Buffer completed at time 75.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 100.0
# Generator 0: Sending tote to Buffer completed at time 125.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 150.0
# Generator 1: Sending tote to Buffer completed at time 175.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 200.0
# Generator 0: Sending tote to Buffer completed at time 225.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 250.0
# Generator 1: Sending tote to Buffer completed at time 275.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 300.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 350.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 400.0
# simulation has ended

# %% [markdown]
# c. Confirm that your simulations produce the correct results, i.e., in correspondence with your lot-time-diagram

# %% [markdown]
# ## Exercise 8: Lift accurately modelled (5 points)
#
# Assume that the Lift starts from the ground floor. If it has to go to level $i \in \{0, Level - 1\}$, it needs to travel a
# distance $dl \cdot (i + 1)$, pick up the tote, travel back, and deliver the tote at the ground floor. For traveling the required
# distance, the vehicle first goes with a constant acceleration `al` *m/s$^2$* until it reaches its maximum velocity `vmaxl`, then
# it moves with this velocity and decelerates with a constant deceleration `al` to approach its destination tier. If the tier
# is located too close to the ground floor, it is possible that the Lift will not reach its maximum speed.

# %% [markdown]
# a. From this information, (analytically) determine the time (in seconds) it takes the Lift to a given tier.

# %% [markdown]
# b. Next, if loading and unloading a tote both take `ll` seconds, determine (analytically) the time it takes the Lift to pick up a tote from tier $i \in \{0, depth - 1\}$ and deliver it to the buffer.

# %% [markdown]
# c. Consider two tiers, and assume that after Tier seconds the first tote arrives (for two tiers: after 0.0 for tier 0 and after 1.0 for tier 1). Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job spends in which Generator, in the Buffer, and spends in the Lift.

# %% [markdown]
# d. Complete the simulation code in the template below.

# %%
# =================================
# # Global variables
# =================================
ll = 2.0        # time to load/unload the lift
bc = 1          # buffer capacity
Level = 2       # the number of tiers
dl = 0.8        # unit height clearance
vmaxl = 5.0     # maximum velocity of lift
al = 7.0        # acceleration/deceleration of lift

# =================================
# # Lift definition
# =================================
def Lift(env, receiving_channel, call_lift_channel, sending_channel):
    while True: 
        ### BEGIN SOLUTION
        lift_called = call_lift_channel.receive()
        yield env.select(lift_called)
        requested_tier = lift_called.received_entity
        
        distance = dl * requested_tier
        if distance <= vmaxl**2/al:
            t_travel = math.sqrt(4*distance/al)
        else:
            t_travel = 2*vmaxl/al  +  (distance-vmaxl**2/al)/vmaxl
        yield env.timeout(t_travel+ll)
        
        receive = receiving_channel.receive()       
        yield env.select(receive)
        x = receive.received_entity
        
        yield env.timeout(t_travel+ll)
        
        send = sending_channel.send(x)
        yield env.select(send)
        ### END SOLUTION
        
        
# =================================
# # Main
# =================================
env = Environment()
a = [Channel(env) for Tier in range(Level)] # a channel for each tier, each sending totes
b = Channel(env)  # for sending totes
c = Channel(env)  # for calling the lift
d = Channel(env)  # for sending totes

Gs = [env.process(Generator(env, a[Tier], Tier)) for Tier in range(Level)] 
B = env.process(Buffer(env, a, b, c))
L = env.process(Lift(env, b, c, d))
E = env.process(Exit(env, d))
env.run()
print ("simulation has ended")
# Out:
# Generator 0: Sending tote to Buffer completed at time 0.0
# Generator 1: Sending tote to Buffer completed at time 1.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 4.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 9.4
# Generator 0: Sending tote to Buffer completed at time 10.0
# Generator 1: Sending tote to Buffer completed at time 11.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 14.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 19.4
# Generator 0: Sending tote to Buffer completed at time 110.0
# Generator 1: Sending tote to Buffer completed at time 111.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 114.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 119.4
# Generator 0: Sending tote to Buffer completed at time 210.0
# Generator 1: Sending tote to Buffer completed at time 211.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 214.0
# Exit:      Tote has completely left the Lift and has been received by the Exit at time 219.4
# simulation has ended

# %% [markdown]
# e. Confirm that your simulations produce the correct results, i.e., in correspondence with your lot-time-diagram

# %% [markdown]
# ## 6.9 Exercise 9: Entire system (10 points)
# In the previous exercises we developed and tested each process individually. Now it is time to combine all processes into one model.

# %% [markdown]
# a. Determine the (total) arrival rate of orders for a system with `Level` tiers, where for each tier orders arrive with a mean inter arrival time of `arrive`.

# %% [markdown]
# b. Complete the simulation code in the template below by substituting the code for the processes as you derived in Exercises 1, 2, 4, 7, and 8. Note that the type tote has been extended in comparison with Exercise 1, so one line of code extra is required in the Generator process to include the tier.

# %%
import time
start_time = time.time()

# =================================
# # Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0.0
    column: int = 0
    tier: int  = 0
        
# =================================
## Global variables
# =================================
lv = 3.0                   # time to load/unload the vehicle
dv = 0.5                   # unit width clearance
vmaxv = 1.5                # maximum velocity of the vehicle
av = 1.0                   # acceleration/deceleration of the vehicle
ll = 2.0                   # time to load/unload the lift
dl = 0.8                   # unit height clearance
vmaxl = 5.0                # maximum velocity of lift
al = 7.0                   # acceleration/deceleration of lift
bc = 1                     # buffer capacity
arrive = 70.0              # inter arrival time of requests
Level = 9                  # the number of tiers
depth  = 55                # the number of columns
number_of_orders = 10000  # the number of orders to process

# =================================
# # Generator definition
# =================================
def Generator(env, sending_channel, Tier):
    ### BEGIN SOLUTION
    ta_dist = lambda: random.exponential(arrive)
    column_dist = lambda:  random.randint(1, depth)
    ### END SOLUTION
    while True:
        x = Tote()
        x.entrytime = env.now
        # x.column = ..... 
        # x.tier = ..... 
        ### BEGIN SOLUTION
        x.column = column_dist()
        x.tier = Tier
        ### END SOLUTION
        send = sending_channel.send(x)
        yield env.select(send)
        # delay = ..... 
        ### BEGIN SOLUTION
        delay = env.timeout(ta_dist())
        ### END SOLUTION
        yield delay
        
        
# =================================
# # Demand Buffer definition
# =================================
def Demand_Buffer(env, receiving_channel, sending_channel):
    xs = [] # list of totes
    while True:
        ### BEGIN SOLUTION
        receiving = receiving_channel.receive() 
        sending = sending_channel.send(xs[0]) if len(xs)>0 else None
        yield env.select(sending,receiving)
        if selected(sending):
            xs = xs[1:]
        if selected(receiving):
            x = receiving.received_entity
            xs = xs + [x]
        ### END SOLUTION
            
            
# =================================
# # Vehicle definition
# =================================
def Vehicle(env, receiving_channel, sending_channel):
    ### BEGIN SOLUTION
    while True: 
        receive = receiving_channel.receive()
        x = yield env.select(receive)
        
        distance = dv*x.column
        if distance <= vmaxv**2/av:
            t_travel = math.sqrt(4*distance/av)
        else:
            t_travel = 2*vmaxv/av  +  (distance-vmaxv**2/av)/vmaxv
        
        # TODO: eigenlijk zou je hier pas het item kunnen ophalen, maar zo wordt het niet gemodelleerd.
        # De reden is natuurlijk dat je in dat geval geen idee hebt waar je naartoe moet rijden. Dit zou eigenlijk eerst verstuurd moeten worden.
        #  x = yield receiving_channel.receive()
        # TODO: Daarnaast, zou je pas kunnen unloaden als er een plekje vrij is in de buffer.
        # Dus pas als de buffer ready is om te ontvangen, heb je nog lv seconden nodig om het ook echt in de buffer te plaatsen.
        #  yield env.timeout(t_travel)
        #  yield sending_channel.readyto_send()
        #  yield env.timeout(lv)
        #  yield sending_channel.send(x)
        te_processing = 2*t_travel+2*lv
        yield env.timeout(te_processing)
        
        send = sending_channel.send(x)  
        yield env.select(send)    
    ### END SOLUTION
    
# =================================
# # Buffer definition
# =================================
def Buffer(env, receiving_channels, sending_channel, call_lift_channel):
    xs = []
    n = [0] * Level
    while True:
        receiving = [receiving_channels[Tier].receive() if n[Tier] < bc else None for Tier in range(Level) ]
        call_lift = call_lift_channel.send(xs[0].tier) if len(xs) > 0 else None
        sending = sending_channel.send(xs[0]) if len(xs) > 0 else None
        communications = receiving + [call_lift] + [sending]
        yield env.select(*communications)
        
        for Tier in range(Level):
            if selected(receiving[Tier]):
                x = receiving[Tier].received_entity
                xs = xs + [x]
                n[Tier] = n[Tier] + 1
        
        if selected(call_lift):
            pass
            
        if selected(sending):
            ### BEGIN SOLUTION
            Tier = xs[0].tier 
            xs = xs[1:]
            n[Tier] = n[Tier] - 1
            ### END SOLUTION
            
# =================================
# # Lift definition
# =================================
def Lift(env, receiving_channel, call_lift_channel, sending_channel):
    while True: 
        ### BEGIN SOLUTION
        lift_called = call_lift_channel.receive()
        yield env.select(lift_called)
        requested_tier = lift_called.received_entity
        
        distance = dl * requested_tier
        if distance <= vmaxl**2/al:
            t_travel = math.sqrt(4*distance/al)
        else:
            t_travel = 2*vmaxl/al  +  (distance-vmaxl**2/al)/vmaxl
        yield env.timeout(t_travel+ll)
        
        receive = receiving_channel.receive()       
        yield env.select(receive)
        x = receive.received_entity
        
        yield env.timeout(t_travel+ll)
        
        send = sending_channel.send(x)
        yield env.select(send)
        ### END SOLUTION
        
# =================================
# # Exit definition
# =================================
def Exit(env, receiving_channel):
    mphi = 0.0
    timer = time.time()
    for i in range(1, number_of_orders + 1):
        receive = receiving_channel.receive()
        yield env.select(receive)
        x = receive.received_entity
    
        mphi = (i - 1) / i * mphi + (env.now - x.entrytime) / i
#         print("tote = %d; Entrytime = %10.4f; Column = %2d; Mean throughput = %8.6f; Mean flowtime = %6.4f\n" %
#              (i , x.entrytime, x.column, i / env.now, mphi ) )

        # Calculate speed of simulation
        if i % 1000 == 0:
            print("--- Totes %s - %s took %s seconds ---" % (i-1000,i, time.time() - timer))
            timer = time.time()
            
        
# =================================
## GDV definition
# =================================
def GDV(env, sending_channel, Tier):
    a = Channel(env)  # for sending totes
    b = Channel(env)  # for sending totes
    G = env.process(Generator(env, a, Tier))
    D = env.process(Demand_Buffer(env, a,b))
    V = env.process(Vehicle(env, b, sending_channel))
        

# =================================
# # Main
# =================================
env = Environment()
c = [Channel(env) for Tier in range(Level)] # a channel for each tier, each sending totes
d = Channel(env)  # for sending totes
e = Channel(env)  # for calling the lift
f = Channel(env)  # for sending totes
GDVs = [ GDV(env, c[Tier], Tier)  for Tier in range(Level) ] 
B = env.process(Buffer(env, c, d, e))
L = env.process(Lift(env, d, e, f))
E = env.process(Exit(env, f))
env.run(until=E)
print ("simulation has ended")

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- Totes 0 - 1000 took 3.140777111053467 seconds ---
# --- Totes 1000 - 2000 took 6.032609224319458 seconds ---
# --- Totes 2000 - 3000 took 10.749584674835205 seconds ---
# --- Totes 3000 - 4000 took 17.1526837348938 seconds ---
# --- Totes 4000 - 5000 took 18.595486879348755 seconds ---
# --- Totes 5000 - 6000 took 20.930529832839966 seconds ---
# --- Totes 6000 - 7000 took 23.45594835281372 seconds ---
# --- Totes 7000 - 8000 took 31.634292125701904 seconds ---
# --- Totes 8000 - 9000 took 33.76323699951172 seconds ---
# --- Totes 9000 - 10000 took 37.076666831970215 seconds ---
# simulation has ended
# --- 202.53975176811218 seconds ---

# %% [markdown]
# c. Verify if the throughput in your simulations matches with the start rate you determined. Verify that totes reach the exit from each tier. Also verify that totes are generated from each column.

# %% [markdown]
# d. Run your simulation 30 times, and record for each run the resulting average throughput and average flow time.
# Determine the mean and the standard deviation of both the average throughput and the average flow time for these 30 simulations. Finally, determine a 95% confidence interval for both the average throughput and the average flow time.

# %% [markdown]
# ## 6.10 Exercise 10: Effect of buffer capacity (10 points)
# Via computer simulation analyze the impact of the buffer capacity on the throughput and flow time (choose values of `bc` as 1,2,3,200). For each setting, run your simulations 30 times and determine both mean and standard deviation of the resulting average throughput and average flow time for these 30 simulations, as well as 95% confidence intervals.

# %% [markdown]
# ## 6.11 Exercise 11: Looking for the best layout (30 points)
# Via computer simulation consider 6 different scenarios (see the table below) that correspond to different layouts of the
# storage facility with a total capacity of 500 totes with different number of tiers and columns.
#
# |  |  |  |  |  | |  |
# | - | - | - | - | - | - | - |
# | Level |  2 | 5 | 10 | 20 | 25 | 50 |
# | Depth | 250 | 100 | 50 | 25 | 20 | 10 |
#
# In order to obtain an answer to the questions below: for each scenario, run your simulations 30 times and determine both mean and standard deviation of the resulting average throughput and average flow time for these 30 simulations, as well as 95% confidence intervals.

# %% [markdown]
# a. For each scenario, determine by means of simulation the maximal throughput.

# %% [markdown]
# b. Assume a required throughput of 6 totes per minute. Compare the resulting flow time for each feasible scenario.

# %% [markdown]
# c. Based on your outcomes, select a layout that seems the best for you. If necessary, introduce other performance indicators and modify the code accordingly. The report on this step should contain an argument to select the best layout.

# %% [markdown]
# ## References
# [1] G. Marchet, M. Melanci, S. Perotti and E. Tappia, "Analytical model to estimate performance of autonomous vehicle storage and retrieval systems for product totes", International Journal of Production Research, vol. 50(24), 7134-7148, 2012.
